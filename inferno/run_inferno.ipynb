# %%
import inferno_opendata
import preproc
import importlib
import train
import plot
import fit
import inferno_config
import hep_model
import stack

# %%
importlib.reload(inferno_opendata)
importlib.reload(preproc)
importlib.reload(train)
importlib.reload(plot)
importlib.reload(hep_model)
importlib.reload(inferno_config)
args = inferno_config.args
args["outpath"] = "/home/centos/mount_point/data/inferno_cmsopen5"
args["downsample_factor"] = None

# %%
samples = inferno_opendata.run_cmsopen(args, epochs = 100, do_fit = False)
# Out:
# *********************
# Training INFERNO and binary-cross entropy (BCE) model
# *********************
#
# *********************
# Outpath /home/centos/mount_point/data/inferno_cmsopen5
# *********************
# Summary features and systematics
# *********************
# Features ['aplanarity', 'chargeEta', 'MET_met', 'deltaPhiTauMet']
# All loaded shape syst ['06_jes', '05_taue', 'jer']
# Shape systematics ['jes']
# Weight systematics []
# Scale shapes [('jes', 0.06)]
# Signal norms {}
# Background norms {}
# Scale norms None
# *********************
# Summary training data
# *********************
# Number of signal training / test events: 20000 23570
# Number of bkg training / test events: 5000 6176
# Use weights True
# Batch size 1000
# x torch.Size([4, 3])
# y tensor([1.])
# w torch.Size([1, 3])
# *********************
# Scaling normalizations of shape systematics
# *********************
# Scaling TTJets_bkg_jes_up from 135.60015823653745 to 143.73616773072973
# Scaling TTJets_bkg_jes_down from 129.17352830620186 to 121.42311660782973
# Scaling WZJets_jes_up from 66.44729314722876 to 70.4341307360625
# Scaling WZJets_jes_down from 58.98015758725496 to 55.441348132019655
# Scaling STJets_jes_up from 31.38053862223635 to 33.263370939570535
# Scaling STJets_jes_down from 28.297219267042443 to 26.599386111019896
# Scaling TTJets_signal_jes_up from 361.5752814461025 to 383.2697983328686
# Scaling TTJets_signal_jes_down from 328.17359646673697 to 308.48318067873277
# *********************
# Summary normalization
# *********************
# Normalization TTJets_bkg 134.10340303520601
# Normalization TTJets_bkg_jes_up 143.73616773072973
# Normalization TTJets_bkg_jes_down 121.42311660782973
# Normalization TTJets_bkg_taue_up 142.10128469430884
# Normalization TTJets_bkg_taue_down 121.00289327263937
# Normalization TTJets_bkg_jer_up 131.1264066173969
# Normalization TTJets_bkg_jer_down 136.69119287774876
# Normalization WZJets 63.68725636342331
# Normalization WZJets_jes_up 70.4341307360625
# Normalization WZJets_jes_down 55.441348132019655
# Normalization WZJets_taue_up 64.59887814981872
# Normalization WZJets_taue_down 62.605488729994875
# Normalization WZJets_jer_up 63.49706201783593
# Normalization WZJets_jer_down 63.50839087651814
# Normalization STJets 30.208598089904672
# Normalization STJets_jes_up 33.263370939570535
# Normalization STJets_jes_down 26.599386111019896
# Normalization STJets_taue_up 30.968770548903976
# Normalization STJets_taue_down 27.850804093379004
# Normalization STJets_jer_up 29.708409086783266
# Normalization STJets_jer_down 30.932922406888746
# Normalization QCD 2690.7227857230937
# Normalization TTJets_signal 348.4525273144509
# Normalization TTJets_signal_jes_up 383.2697983328686
# Normalization TTJets_signal_jes_down 308.48318067873277
# Normalization TTJets_signal_taue_up 357.9410474684114
# Normalization TTJets_signal_taue_down 319.40254684513434
# Normalization TTJets_signal_jer_up 347.01802181401007
# Normalization TTJets_signal_jer_down 349.7573085438872
# Normalization Data 3323.0
# *********************
#
# *********************
# Summary INFERNO model
# *********************
# Learning rate 0.001
# Temperature 0.1
# Neurons 100
# Bins 10
# *********************
# Summary INFERNO callback
# *********************
# b_true 2690.7227857230937
# mu_true 348.4525273144509
# n_shape_systs 1
# n_weight_systs 0
# nshape_alphas 1
# shape idx [1]
# shape_norm_sigma [(0.885294714480148, 1.0999196972016734)]
# s_norm_sigma []
# s_norm_idxs []
# b_norm_sigma []
# b_norm_idxs []
# b_rate_param False
# b_rate_param_idx []
# n_alpha 2
# interp_algo default
# use_hist False
# sigmoid delta 200.0
# ignore_loss False
# ignore_shape_norm False
# asymm_shape_norm True
# *********************
# 1: Train=1601.4438427734376 Valid=1116.8416455078125
# 2: Train=1151.3292358398437 Valid=1058.9921215820314
# 3: Train=1102.4497241210938 Valid=1019.315322265625
# 4: Train=1058.9778466796874 Valid=989.6311987304688
# 5: Train=1022.1830541992188 Valid=977.5637817382812
# 6: Train=999.3499780273437 Valid=959.5273461914062
# 7: Train=978.1816723632812 Valid=945.5742407226562
# 8: Train=961.0303930664063 Valid=930.2781860351563
# 9: Train=955.6666577148437 Valid=924.7152197265625
# 10: Train=945.2008837890625 Valid=930.1049194335938
# 11: Train=934.193935546875 Valid=915.1687036132812
# 12: Train=930.3539624023438 Valid=914.4898754882812
# 13: Train=918.6008349609375 Valid=915.8951879882812
# 14: Train=925.8393798828125 Valid=892.1778051757813
# 15: Train=906.4001440429688 Valid=906.1801416015625
# 16: Train=903.4703344726563 Valid=895.8700024414062
# 17: Train=897.8431420898437 Valid=908.233955078125
# 18: Train=902.344873046875 Valid=906.08794921875
# 19: Train=892.199970703125 Valid=905.0991357421875
# 20: Train=888.24140625 Valid=892.9737524414063
# 21: Train=889.973232421875 Valid=910.825146484375
# 22: Train=904.085791015625 Valid=887.536298828125
# 23: Train=886.5157299804688 Valid=894.2061547851563
# 24: Train=881.5853491210937 Valid=875.6083813476563
# 25: Train=877.8487524414063 Valid=894.4368334960938
# 26: Train=873.9232421875 Valid=877.7698779296875
# 27: Train=863.2762451171875 Valid=889.1472631835937
# 28: Train=864.465146484375 Valid=890.8065283203125
# 29: Train=882.2349658203125 Valid=908.2980444335938
# 30: Train=900.899658203125 Valid=893.1094458007813
# 31: Train=871.2507250976563 Valid=887.9826123046874
# 32: Train=900.5823901367188 Valid=902.7000048828126
# 33: Train=893.6250659179688 Valid=918.7659936523437
# 34: Train=889.105595703125 Valid=895.0654711914062
# 35: Train=863.6092260742188 Valid=884.3122485351563
# 36: Train=851.3429321289062 Valid=881.3466723632813
# 37: Train=855.0670141601563 Valid=880.5852319335937
# 38: Train=841.2187182617188 Valid=880.6765844726563
# 39: Train=862.761650390625 Valid=917.4533325195313
# 40: Train=867.0819018554688 Valid=873.3592504882813
# 41: Train=848.8091870117188 Valid=867.2920361328125
# 42: Train=849.8493676757812 Valid=875.5629516601563
# 43: Train=843.0394702148437 Valid=860.9777490234375
# 44: Train=831.4702221679687 Valid=872.9636352539062
# 45: Train=845.7629223632813 Valid=863.250537109375
# 46: Train=836.9371801757812 Valid=871.5880297851562
# 47: Train=837.6701513671875 Valid=870.0815991210937
# 48: Train=816.2271362304688 Valid=867.2815576171874
# 49: Train=827.805068359375 Valid=864.858515625
# 50: Train=826.3053735351563 Valid=867.6432739257813
# 51: Train=847.8301318359376 Valid=871.460380859375
# 52: Train=845.2963793945313 Valid=885.5585571289063
# 53: Train=823.4083569335937 Valid=879.1093872070312
# 54: Train=819.365458984375 Valid=858.8784887695313
# 55: Train=812.9612109375 Valid=871.35962890625
# 56: Train=823.2907006835937 Valid=866.3147119140625
# 57: Train=824.9318212890626 Valid=869.4708764648437
# 58: Train=830.1926782226562 Valid=874.19552734375
# 59: Train=810.8775048828124 Valid=879.4890063476563
# 60: Train=830.9351977539062 Valid=868.618330078125
# 61: Train=817.0495068359374 Valid=852.0871264648438
# 62: Train=819.5098071289062 Valid=862.1047680664062
# 63: Train=828.6917211914063 Valid=862.54302734375
# 64: Train=833.6690356445313 Valid=859.3741137695313
# 65: Train=825.8182495117187 Valid=861.1999072265625
# 66: Train=808.6758813476563 Valid=856.4532641601562
# 67: Train=813.8564404296875 Valid=856.1117065429687
# 68: Train=813.4748681640625 Valid=863.16427734375
# 69: Train=809.3821606445313 Valid=861.2054272460938
# 70: Train=821.217353515625 Valid=851.6402587890625
# 71: Train=821.329609375 Valid=857.74376953125
# 72: Train=808.3148461914062 Valid=860.8113549804688
# 73: Train=801.9106811523437 Valid=860.2331518554688
# 74: Train=808.8467431640624 Valid=855.2227978515625
# 75: Train=799.1307641601562 Valid=860.011728515625
# 76: Train=801.8416064453126 Valid=852.1748266601562
# 77: Train=826.5878271484376 Valid=860.4164013671875
# 78: Train=798.8066870117187 Valid=858.6373291015625
# 79: Train=808.420673828125 Valid=851.9169848632813
# 80: Train=800.1309301757813 Valid=849.982685546875
# 81: Train=796.9388525390625 Valid=858.4511669921875
# 82: Train=821.7712646484375 Valid=872.0952880859375
# 83: Train=827.3300927734375 Valid=862.362197265625
# 84: Train=816.2543725585938 Valid=867.8642895507812
# 85: Train=815.0283227539062 Valid=854.6647827148438
# 86: Train=819.1066088867187 Valid=864.985068359375
# 87: Train=813.5880200195312 Valid=861.2879345703125
# 88: Train=817.253447265625 Valid=872.97671875
# 89: Train=832.8223876953125 Valid=875.1019995117188
# 90: Train=824.2534008789063 Valid=873.5152490234375
# 91: Train=828.7955834960937 Valid=869.362939453125
# 92: Train=815.7016625976562 Valid=877.2105517578125
# 93: Train=822.197109375 Valid=857.0590942382812
# 94: Train=812.60310546875 Valid=848.8399169921875
# 95: Train=808.2857055664062 Valid=844.6661572265625
# 96: Train=824.521318359375 Valid=868.5458129882812
# 97: Train=816.9490942382813 Valid=858.4275512695312
# 98: Train=798.9689013671875 Valid=871.802470703125
# 99: Train=811.7123022460937 Valid=855.348193359375
# 100: Train=801.3383935546875 Valid=852.9435180664062
# Loading best model with loss 844.6661572265625
# Evaluating best INFERNO model from epoch 94 with loss 844.6661572265625
# *********************
# Summary BCE model
# *********************
# Learning rate 0.001
# Neurons 20
# *********************
# Summary INFERNO callback
# *********************
# b_true 2690.7227857230937
# mu_true 348.4525273144509
# n_shape_systs 1
# n_weight_systs 0
# nshape_alphas 1
# shape idx [1]
# shape_norm_sigma [(0.885294714480148, 1.0999196972016734)]
# s_norm_sigma []
# s_norm_idxs []
# b_norm_sigma []
# b_norm_idxs []
# b_rate_param False
# b_rate_param_idx []
# n_alpha 2
# interp_algo default
# use_hist True
# sigmoid delta 200.0
# ignore_loss True
# ignore_shape_norm False
# asymm_shape_norm True
# *********************
# 1: Train=0.7014244723320008 Valid=0.6592835688591003
# 2: Train=0.6078869318962097 Valid=0.5759074211120605
# 3: Train=0.5181683707237243 Valid=0.5115323090553283
# 4: Train=0.45649484157562253 Valid=0.47061403512954714
# 5: Train=0.41891088128089904 Valid=0.44377630472183227
# 6: Train=0.39634787797927856 Valid=0.42649150371551514
# 7: Train=0.38160961627960205 Valid=0.413540403842926
# 8: Train=0.3704446303844452 Valid=0.40243414163589475
# 9: Train=0.36403114318847657 Valid=0.3969887506961822
# 10: Train=0.3551169729232788 Valid=0.3865715420246124
# 11: Train=0.3470551073551178 Valid=0.3790501916408539
# 12: Train=0.33968674898147583 Valid=0.3729055345058441
# 13: Train=0.33281672596931455 Valid=0.36523592948913575
# 14: Train=0.3301373779773712 Valid=0.3587275063991547
# 15: Train=0.3246907138824463 Valid=0.3542720329761505
# 16: Train=0.32357350587844846 Valid=0.3493488240242004
# 17: Train=0.32002193212509156 Valid=0.34660829305648805
# 18: Train=0.3171484172344208 Valid=0.34355022430419924
# 19: Train=0.31489640593528745 Valid=0.3429152429103851
# 20: Train=0.31312293648719786 Valid=0.3403301894664764
# 21: Train=0.3118606233596802 Valid=0.33964231729507444
# 22: Train=0.3104829728603363 Valid=0.33721736550331116
# 23: Train=0.31295709729194643 Valid=0.3379117381572723
# 24: Train=0.3120281267166138 Valid=0.33459590435028075
# 25: Train=0.31123787522315977 Valid=0.33565855145454404
# 26: Train=0.31067386746406556 Valid=0.33532770156860353
# 27: Train=0.310061913728714 Valid=0.33291593074798587
# 28: Train=0.30969767928123476 Valid=0.33349175453186036
# 29: Train=0.3058673369884491 Valid=0.3327874529361725
# 30: Train=0.30518505930900575 Valid=0.3328855574131012
# 31: Train=0.3048214066028595 Valid=0.33300262212753295
# 32: Train=0.30448639392852783 Valid=0.3313430118560791
# 33: Train=0.3041015434265137 Valid=0.33092495560646057
# 34: Train=0.30357363939285276 Valid=0.3317528700828552
# 35: Train=0.30317309737205506 Valid=0.33053707242012026
# 36: Train=0.29943876624107363 Valid=0.33178152680397033
# 37: Train=0.2991148507595062 Valid=0.3310802340507507
# 38: Train=0.29871799230575563 Valid=0.3302494263648987
# 39: Train=0.2984842038154602 Valid=0.3295500147342682
# 40: Train=0.2947946697473526 Valid=0.3298621761798859
# 41: Train=0.2945335698127747 Valid=0.33097281217575075
# 42: Train=0.29421599984169006 Valid=0.3287695932388306
# 43: Train=0.29410932064056394 Valid=0.3315426468849182
# 44: Train=0.29386339664459227 Valid=0.330847350358963
# 45: Train=0.2937741935253143 Valid=0.3271421015262604
# 46: Train=0.2933893263339996 Valid=0.3309042155742645
# 47: Train=0.2931308889389038 Valid=0.3278787839412689
# 48: Train=0.29289950370788576 Valid=0.32717937707901
# 49: Train=0.2927482289075851 Valid=0.32955321073532107
# 50: Train=0.29261202454566954 Valid=0.32860800981521604
# 51: Train=0.29227539598941804 Valid=0.3287913930416107
# 52: Train=0.29207735300064086 Valid=0.3275746846199036
# 53: Train=0.29187860727310183 Valid=0.3270832324028015
# 54: Train=0.29173102498054504 Valid=0.3273848009109497
# 55: Train=0.29146143853664397 Valid=0.32787059783935546
# 56: Train=0.2913436496257782 Valid=0.3243433046340942
# 57: Train=0.2877937626838684 Valid=0.3226595401763916
# 58: Train=0.28763309836387635 Valid=0.32579030632972716
# 59: Train=0.2874597322940826 Valid=0.32399782419204715
# 60: Train=0.28712052702903745 Valid=0.3232342505455017
# 61: Train=0.2867538404464722 Valid=0.321934187412262
# 62: Train=0.2865213978290558 Valid=0.32416372060775756
# 63: Train=0.2864249897003174 Valid=0.32215542197227476
# 64: Train=0.2860210502147675 Valid=0.3218001961708069
# 65: Train=0.2858175575733185 Valid=0.3241277039051056
# 66: Train=0.28552956104278565 Valid=0.32308286905288697
# 67: Train=0.2854151177406311 Valid=0.3230911159515381
# 68: Train=0.2850196659564972 Valid=0.32281113386154175
# 69: Train=0.2845334815979004 Valid=0.3220701789855957
# 70: Train=0.2843745917081833 Valid=0.32080102324485776
# 71: Train=0.28403590321540834 Valid=0.3206068515777588
# 72: Train=0.2838252049684524 Valid=0.3206666660308838
# 73: Train=0.283485369682312 Valid=0.3206768560409546
# 74: Train=0.2834513020515442 Valid=0.32479987502098084
# 75: Train=0.28333968937397 Valid=0.3183193290233612
# 76: Train=0.2830197614431381 Valid=0.31945890188217163
# 77: Train=0.2827028965950012 Valid=0.3199433124065399
# 78: Train=0.2822648739814758 Valid=0.32155916213989255
# 79: Train=0.28223668098449706 Valid=0.32166229248046874
# 80: Train=0.28202309608459475 Valid=0.3193912994861603
# 81: Train=0.2818746197223663 Valid=0.32149120926856994
# 82: Train=0.2819502431154251 Valid=0.3200044894218445
# 83: Train=0.2817334109544754 Valid=0.32038599014282226
# 84: Train=0.28157012939453124 Valid=0.3208459258079529
# 85: Train=0.28152653872966765 Valid=0.3198535466194153
# 86: Train=0.28146655440330504 Valid=0.32246622681617737
# 87: Train=0.281449716091156 Valid=0.3193515908718109
# 88: Train=0.2813212931156158 Valid=0.31971230030059816
# 89: Train=0.28128503262996674 Valid=0.32079307675361635
# 90: Train=0.2811710858345032 Valid=0.3205980885028839
# 91: Train=0.28126772463321686 Valid=0.3184818124771118
# 92: Train=0.2813600158691406 Valid=0.3178683614730835
# 93: Train=0.2812498950958252 Valid=0.3208368170261383
# 94: Train=0.2810105550289154 Valid=0.32035247921943666
# 95: Train=0.2811438381671906 Valid=0.3183966088294983
# 96: Train=0.2811982834339142 Valid=0.31961272239685057
# 97: Train=0.28091460824012754 Valid=0.3192831802368164
# 98: Train=0.2810227906703949 Valid=0.32012164711952207
# 99: Train=0.28092931270599364 Valid=0.3202539563179016
# 100: Train=0.28094425082206725 Valid=0.3183992600440979
# Loading best model with loss 0.3178683614730835
# Evaluating best BCE model from epoch 91 with loss 0.3178683614730835
# *********************
# Predicting inferno samples
# *********************
# Predicting bce samples
# *********************
# Finished training
# *********************

# %%
importlib.reload(inferno_opendata)
importlib.reload(preproc)
importlib.reload(train)
importlib.reload(plot)
importlib.reload(fit)
importlib.reload(inferno_config)
importlib.reload(stack)
samples = inferno_opendata.run_cmsopen(args, retrain = False, do_fit = True)
# Out:
# *********************
# Fitting INFERNO and binary-cross entropy (BCE) model
# *********************
#
# *********************
# Outpath /home/centos/mount_point/data/inferno_cmsopen5
# *********************
# Summary features and systematics
# *********************
# Features ['aplanarity', 'chargeEta', 'MET_met', 'deltaPhiTauMet']
# All loaded shape syst ['06_jes', '05_taue', 'jer']
# Shape systematics ['jes']
# Weight systematics []
# Scale shapes [('jes', 0.06)]
# Signal norms {}
# Background norms {}
# Scale norms None
# *********************
# Loading samples from path /home/centos/mount_point/data/inferno_cmsopen5
# *********************
# Excluding samples used in training
# *********************
# Create ROOT trees
# Normalization TTJets_bkg 134.10340303520601
# Normalization TTJets_bkg_jes_up 143.73616773072973
# Normalization TTJets_bkg_jes_down 121.42311660782973
# Normalization WZJets 63.68725636342331
# Normalization WZJets_jes_up 70.4341307360625
# Normalization WZJets_jes_down 55.441348132019655
# Normalization STJets 30.208598089904672
# Normalization STJets_jes_up 33.263370939570535
# Normalization STJets_jes_down 26.599386111019896
# Normalization QCD 2690.722785723094
# Normalization TTJets_signal 348.4525273144509
# Normalization TTJets_signal_jes_up 383.26979833286856
# Normalization TTJets_signal_jes_down 308.4831806787328
# Normalization Data 3323.0
# *********************
# Summary fit args
# *********************
# Fit model signal_only
# Fit norms {}
# Fit shape systematics ['jes']
# Fit asimov True
# Fit data False
# Fit significance True
# Fit float QCD True
# Prune stat error True
# Minos ['mu']
# Scan n steps 200
# *********************
# Fit bce asimov
# INFO - cabinetry.tabulate - yields per channel for pre-fit model prediction:
# ╒═══════════════╤═════════════════╕
# │ sample        │ Signal_region   │
# ╞═══════════════╪═════════════════╡
# │ QCD           │ 2690.72         │
# ├───────────────┼─────────────────┤
# │ STJets        │ 30.21           │
# ├───────────────┼─────────────────┤
# │ TTJets_bkg    │ 134.10          │
# ├───────────────┼─────────────────┤
# │ TTJets_signal │ 348.45          │
# ├───────────────┼─────────────────┤
# │ WZJets        │ 63.69           │
# ├───────────────┼─────────────────┤
# │ total         │ 3267.17 ± 37.39 │
# ├───────────────┼─────────────────┤
# │ data          │ 3267.17         │
# ╘═══════════════╧═════════════════╛
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - MINUIT status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 77.75                      │              Nfcn = 61               │
# │ EDM = 1.91e-13 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │        No Parameters at limit        │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │  Covariance   │     Hesse ok     │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# INFO - cabinetry.fit - running MINOS for mu
# INFO - cabinetry.fit - MINOS results:
# INFO - cabinetry.fit - mu                =  1.0000 -0.1161 +0.1472
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - QCD_norm          =  1.0000 +/- 0.0220
# INFO - cabinetry.fit - mu                =  1.0000 +/- 0.1285
# INFO - cabinetry.fit - TTJets_signal_jes =  0.0000 +/- 0.9665
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# WARNING - cabinetry.histo - Signal_region_Data has empty bins: [9]
# WARNING - cabinetry.histo - Signal_region_WZJets has empty bins: [0 7 9]
# {'mu': (-0.1160718875378838, 0.1471910257609701)}
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W VariableMetricBuilder No improvement in line search
# {'mu': (-0.09719381537277648, 0.09972481627541926)}
# *********************
# Fit inferno asimov
# WARNING - cabinetry.histo - Signal_region_Data has empty bins: [9]
# WARNING - cabinetry.histo - Signal_region_WZJets has empty bins: [0 7 9]
# INFO - cabinetry.tabulate - yields per channel for pre-fit model prediction:
# ╒═══════════════╤═════════════════╕
# │ sample        │ Signal_region   │
# ╞═══════════════╪═════════════════╡
# │ QCD           │ 2690.72         │
# ├───────────────┼─────────────────┤
# │ STJets        │ 30.21           │
# ├───────────────┼─────────────────┤
# │ TTJets_bkg    │ 134.10          │
# ├───────────────┼─────────────────┤
# │ TTJets_signal │ 348.45          │
# ├───────────────┼─────────────────┤
# │ WZJets        │ 63.69           │
# ├───────────────┼─────────────────┤
# │ total         │ 3267.17 ± 37.39 │
# ├───────────────┼─────────────────┤
# │ data          │ 3267.17         │
# ╘═══════════════╧═════════════════╛
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - MINUIT status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 55.52                      │              Nfcn = 68               │
# │ EDM = 1.82e-12 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │        No Parameters at limit        │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │  Covariance   │     Hesse ok     │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# INFO - cabinetry.fit - running MINOS for mu
# INFO - cabinetry.fit - MINOS results:
# INFO - cabinetry.fit - mu                =  1.0000 -0.1011 +0.1112
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - QCD_norm          =  1.0000 +/- 0.0223
# INFO - cabinetry.fit - mu                =  1.0000 +/- 0.1053
# INFO - cabinetry.fit - TTJets_signal_jes = -0.0000 +/- 0.7102
# {'mu': (-0.10106587364658016, 0.11123049183687246)}
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# {'mu': (-0.09543800174992564, 0.09860686825632084)}
# *****************
# Summary bce asimov
# QCD_norm 1.0 +- 0.022
# mu 1.0 +- 0.128
# TTJets_signal_jes 0.0 +- 0.966
# Minos uncertainty mu -0.1160718875378838 0.1471910257609701
# Correlation matrix
# [[ 1.         -0.17401353 -0.12909549]
#  [-0.17401353  1.         -0.64262421]
#  [-0.12909549 -0.64262421  1.        ]]
# Significance expected 11.896615329477953
# Significance observed 11.896614904648414
# *****************
# *****************
# Summary inferno asimov
# QCD_norm 1.0 +- 0.022
# mu 1.0 +- 0.105
# TTJets_signal_jes -0.0 +- 0.71
# Minos uncertainty mu -0.10106587364658016 0.11123049183687246
# Correlation matrix
# [[ 1.         -0.21378473 -0.21565974]
#  [-0.21378473  1.         -0.38878111]
#  [-0.21565974 -0.38878111  1.        ]]
# Significance expected 12.96280211778218
# Significance observed 12.962802106597335
# *****************
