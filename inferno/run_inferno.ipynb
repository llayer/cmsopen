# %%
import inferno_opendata
import preproc
import importlib
import train
import plot
import fit
import inferno_config
import hep_model
import stack

# %%
importlib.reload(inferno_opendata)
importlib.reload(preproc)
importlib.reload(train)
importlib.reload(plot)
importlib.reload(hep_model)
importlib.reload(inferno_config)
args = inferno_config.args
args["outpath"] = "/home/centos/mount_point/data/test"
args["temperature"] = 0.5
args["bins"] = 15
args["downsample_factor"] = None

# %%
samples = inferno_opendata.run_cmsopen(args, epochs = 100, do_fit = False)
# Out:
# *********************
# Training INFERNO and binary-cross entropy (BCE) model
# *********************
#
# *********************
# Outpath /home/centos/mount_point/data/test
# *********************
# Summary features and systematics
# *********************
# Features ['aplanarity', 'chargeEta', 'MET_met', 'deltaPhiTauMet']
# All loaded shape syst ['06_jes', 'taue', 'jer']
# Shape systematics ['jes']
# Weight systematics []
# Scale shapes [('jes', 0.06)]
# Signal norms {}
# Background norms {}
# Scale norms None
# *********************
# Summary training data
# *********************
# Number of signal training / test events: 20000 23570
# Number of bkg training / test events: 5000 6176
# Use weights True
# Batch size 1000
# x torch.Size([4, 3])
# y tensor([1.])
# w torch.Size([1, 3])
# *********************
# Scaling normalizations of shape systematics
# *********************
# Scaling TTJets_bkg_jes_up from 135.60015823653745 to 143.73616773072973
# Scaling TTJets_bkg_jes_down from 129.17352830620186 to 121.42311660782973
# Scaling WZJets_jes_up from 66.44729314722876 to 70.4341307360625
# Scaling WZJets_jes_down from 58.98015758725496 to 55.441348132019655
# Scaling STJets_jes_up from 31.38053862223635 to 33.263370939570535
# Scaling STJets_jes_down from 28.297219267042443 to 26.599386111019896
# Scaling TTJets_signal_jes_up from 361.5752814461025 to 383.2697983328686
# Scaling TTJets_signal_jes_down from 328.17359646673697 to 308.48318067873277
# *********************
# Summary normalization
# *********************
# Normalization TTJets_bkg 134.10340303520601
# Normalization TTJets_bkg_jes_up 143.73616773072973
# Normalization TTJets_bkg_jes_down 121.42311660782973
# Normalization TTJets_bkg_taue_up 139.34421652696145
# Normalization TTJets_bkg_taue_down 126.24503090853688
# Normalization TTJets_bkg_jer_up 131.1264066173969
# Normalization TTJets_bkg_jer_down 136.69119287774876
# Normalization WZJets 63.68725636342331
# Normalization WZJets_jes_up 70.4341307360625
# Normalization WZJets_jes_down 55.441348132019655
# Normalization WZJets_taue_up 62.8582210399258
# Normalization WZJets_taue_down 61.78838537033156
# Normalization WZJets_jer_up 63.49706201783593
# Normalization WZJets_jer_down 63.50839087651814
# Normalization STJets 30.208598089904672
# Normalization STJets_jes_up 33.263370939570535
# Normalization STJets_jes_down 26.599386111019896
# Normalization STJets_taue_up 30.729174455555878
# Normalization STJets_taue_down 28.82001988364199
# Normalization STJets_jer_up 29.708409086783266
# Normalization STJets_jer_down 30.932922406888746
# Normalization QCD 2690.7227857230937
# Normalization TTJets_signal 348.4525273144509
# Normalization TTJets_signal_jes_up 383.2697983328686
# Normalization TTJets_signal_jes_down 308.48318067873277
# Normalization TTJets_signal_taue_up 355.0448159528873
# Normalization TTJets_signal_taue_down 331.4043246150461
# Normalization TTJets_signal_jer_up 347.01802181401007
# Normalization TTJets_signal_jer_down 349.7573085438872
# Normalization Data 3323.0
# *********************
#
# *********************
# Summary INFERNO model
# *********************
# Learning rate 0.001
# Temperature 0.1
# Neurons 100
# Bins 15
# *********************
# Summary INFERNO callback
# *********************
# b_true 2690.7227857230937
# mu_true 348.4525273144509
# n_shape_systs 1
# n_weight_systs 0
# nshape_alphas 1
# shape idx [1]
# shape_norm_sigma [(0.885294714480148, 1.0999196972016734)]
# s_norm_sigma []
# s_norm_idxs []
# b_norm_sigma []
# b_norm_idxs []
# b_rate_param False
# b_rate_param_idx []
# n_alpha 2
# interp_algo default
# use_hist False
# sigmoid delta 200.0
# ignore_loss False
# ignore_shape_norm False
# asymm_shape_norm True
# *********************
# 1: Train=1558.30953125 Valid=1152.5941284179687
# 2: Train=1109.7603125 Valid=1084.9041845703125
# 3: Train=1058.2642431640625 Valid=1042.0157983398437
# 4: Train=1017.9228173828125 Valid=1009.7857446289063
# 5: Train=1000.5301123046875 Valid=1003.1828881835937
# 6: Train=973.997763671875 Valid=985.6814599609374
# 7: Train=963.5755712890625 Valid=982.4597290039062
# 8: Train=958.8576586914063 Valid=963.9806884765625
# 9: Train=939.0818725585938 Valid=960.0059936523437
# 10: Train=934.3263696289063 Valid=947.6870776367188
# 11: Train=923.7445141601562 Valid=932.4419384765625
# 12: Train=917.0206494140625 Valid=933.6828247070313
# 13: Train=907.6189013671875 Valid=915.8443627929687
# 14: Train=894.5893701171875 Valid=910.1452319335938
# 15: Train=884.4585815429688 Valid=903.3892822265625
# 16: Train=887.545341796875 Valid=902.3928002929688
# 17: Train=881.253193359375 Valid=895.0326391601562
# 18: Train=878.6096166992188 Valid=901.4263989257812
# 19: Train=865.25880859375 Valid=886.1165576171875
# 20: Train=855.1396459960938 Valid=891.535791015625
# 21: Train=860.4103637695313 Valid=887.0665161132813
# 22: Train=851.6865502929687 Valid=881.7898168945312
# 23: Train=852.4943188476562 Valid=888.1894262695313
# 24: Train=841.6439501953125 Valid=875.1175048828125
# 25: Train=838.8141333007812 Valid=875.9195043945313
# 26: Train=841.78044921875 Valid=872.9512719726563
# 27: Train=839.5651000976562 Valid=878.1841137695312
# 28: Train=835.6275341796875 Valid=862.1334057617188
# 29: Train=830.338701171875 Valid=866.0303857421875
# 30: Train=831.4110986328125 Valid=868.8637744140625
# 31: Train=833.4169189453125 Valid=865.095263671875
# 32: Train=818.936201171875 Valid=860.4793383789063
# 33: Train=826.77234375 Valid=857.0011791992188
# 34: Train=814.9517431640625 Valid=856.00771484375
# 35: Train=816.7362426757812 Valid=851.0603881835938
# 36: Train=812.9138134765625 Valid=849.7703857421875
# 37: Train=825.8297412109375 Valid=846.917861328125
# 38: Train=832.6528466796875 Valid=856.5285986328125
# 39: Train=816.9249560546875 Valid=857.6095947265625
# 40: Train=808.6380810546875 Valid=849.5231372070313
# 41: Train=810.3349267578125 Valid=851.7332836914062
# 42: Train=796.2025927734375 Valid=864.537314453125
# 43: Train=801.6844287109375 Valid=859.3716674804688
# 44: Train=809.7809887695313 Valid=850.3355541992188
# 45: Train=799.7603930664062 Valid=853.7694067382813
# 46: Train=823.6221606445313 Valid=856.4141870117187
# 47: Train=830.336640625 Valid=854.8566918945312
# 48: Train=849.8185668945313 Valid=873.7222680664063
# 49: Train=867.59748046875 Valid=872.9553125
# 50: Train=846.3309008789063 Valid=865.3922509765625
# 51: Train=841.1083837890625 Valid=853.5524365234374
# 52: Train=842.3252392578125 Valid=858.5201147460938
# 53: Train=851.7560668945313 Valid=877.2187060546875
# 54: Train=847.752265625 Valid=867.9032202148437
# 55: Train=829.3182861328125 Valid=860.0881030273438
# 56: Train=826.6144677734375 Valid=848.3569995117188
# 57: Train=839.1384350585937 Valid=863.51591796875
# 58: Train=843.7624072265625 Valid=861.9396948242188
# 59: Train=844.4565747070312 Valid=874.6880200195312
# 60: Train=833.573486328125 Valid=872.2967358398438
# 61: Train=831.0959448242188 Valid=858.0798413085937
# 62: Train=843.4135620117188 Valid=876.799287109375
# 63: Train=835.4064965820312 Valid=857.203212890625
# 64: Train=803.8665576171875 Valid=854.0141088867188
# 65: Train=825.0269653320313 Valid=836.637919921875
# 66: Train=819.417978515625 Valid=866.8914819335937
# 67: Train=812.8335668945313 Valid=855.3955834960938
# 68: Train=819.1284912109375 Valid=834.8460302734375
# 69: Train=804.689306640625 Valid=856.3620678710937
# 70: Train=823.8105541992187 Valid=848.719248046875
# 71: Train=823.5381567382813 Valid=838.525712890625
# 72: Train=807.0535791015625 Valid=816.1630932617187
# 73: Train=800.1345263671875 Valid=829.8623754882813
# 74: Train=796.4740673828124 Valid=812.7909326171875
# 75: Train=800.0945288085937 Valid=821.00630859375
# 76: Train=781.467421875 Valid=832.0498071289062
# 77: Train=818.37404296875 Valid=817.592568359375
# 78: Train=800.9693530273438 Valid=844.53162109375
# 79: Train=842.8390673828125 Valid=862.1904028320313
# 80: Train=861.9157299804688 Valid=861.5462280273438
# 81: Train=864.4390844726563 Valid=885.745673828125
# 82: Train=851.2740869140625 Valid=856.4271923828124
# 83: Train=812.2722436523437 Valid=834.0505615234375
# 84: Train=813.957275390625 Valid=840.672333984375
# 85: Train=799.3614721679687 Valid=835.023740234375
# 86: Train=805.39515625 Valid=825.918447265625
# 87: Train=792.2756127929688 Valid=797.7403588867187
# 88: Train=776.2501318359375 Valid=798.2959130859375
# 89: Train=767.7080615234376 Valid=807.4432568359375
# 90: Train=813.7157958984375 Valid=805.8257299804687
# 91: Train=830.6533813476562 Valid=812.2289111328125
# 92: Train=804.4308642578125 Valid=812.2124169921875
# 93: Train=815.1625415039063 Valid=811.4023852539062
# 94: Train=782.6685986328125 Valid=791.7443237304688
# 95: Train=776.8041064453125 Valid=813.8732885742188
# 96: Train=774.840869140625 Valid=822.0431567382813
# 97: Train=822.305849609375 Valid=834.1889770507812
# 98: Train=784.1068823242188 Valid=841.546611328125
# 99: Train=829.8048779296874 Valid=841.6035546875
# 100: Train=811.3021264648437 Valid=872.585361328125
# Loading best model with loss 791.7443237304688
# Evaluating best INFERNO model from epoch 93 with loss 791.7443237304688
# *********************
# Summary BCE model
# *********************
# Learning rate 0.001
# Neurons 20
# *********************
# Summary INFERNO callback
# *********************
# b_true 2690.7227857230937
# mu_true 348.4525273144509
# n_shape_systs 1
# n_weight_systs 0
# nshape_alphas 1
# shape idx [1]
# shape_norm_sigma [(0.885294714480148, 1.0999196972016734)]
# s_norm_sigma []
# s_norm_idxs []
# b_norm_sigma []
# b_norm_idxs []
# b_rate_param False
# b_rate_param_idx []
# n_alpha 2
# interp_algo default
# use_hist True
# sigmoid delta 200.0
# ignore_loss True
# ignore_shape_norm False
# asymm_shape_norm True
# *********************
# 1: Train=0.7079991817474365 Valid=0.6843531918525696
# 2: Train=0.6551161766052246 Valid=0.6391732859611511
# 3: Train=0.5968141603469849 Valid=0.5892990732192993
# 4: Train=0.5341311800479889 Valid=0.5407611441612243
# 5: Train=0.48072237491607667 Valid=0.5018298983573913
# 6: Train=0.44191344499588014 Valid=0.4718992674350739
# 7: Train=0.4150575566291809 Valid=0.45078649044036867
# 8: Train=0.39699290990829467 Valid=0.4355682134628296
# 9: Train=0.38440584182739257 Valid=0.423398597240448
# 10: Train=0.3779039025306702 Valid=0.4184989058971405
# 11: Train=0.3692256665229797 Valid=0.4089392590522766
# 12: Train=0.3606483852863312 Valid=0.39946610569953916
# 13: Train=0.3522529649734497 Valid=0.3933879005908966
# 14: Train=0.3437491250038147 Valid=0.3830722677707672
# 15: Train=0.33560689210891725 Valid=0.3786858522891998
# 16: Train=0.32817628264427184 Valid=0.37125004291534425
# 17: Train=0.32149410486221314 Valid=0.36525731921195986
# 18: Train=0.3157019519805908 Valid=0.3595146358013153
# 19: Train=0.31108540773391724 Valid=0.35598446369171144
# 20: Train=0.3074172472953796 Valid=0.35308234333992006
# 21: Train=0.30423469305038453 Valid=0.352193763256073
# 22: Train=0.30171437859535216 Valid=0.34951868176460266
# 23: Train=0.29974596738815307 Valid=0.34686454057693483
# 24: Train=0.29809254348278047 Valid=0.34604288220405577
# 25: Train=0.29670175790786746 Valid=0.3442194426059723
# 26: Train=0.29551705479621887 Valid=0.3458455681800842
# 27: Train=0.29460750460624696 Valid=0.3447460722923279
# 28: Train=0.29366450309753417 Valid=0.3420559883117676
# 29: Train=0.2928559422492981 Valid=0.3418115019798279
# 30: Train=0.29226877450942995 Valid=0.3409408903121948
# 31: Train=0.29157702684402464 Valid=0.34308505535125733
# 32: Train=0.2912224733829498 Valid=0.33666248559951784
# 33: Train=0.2907725834846497 Valid=0.33683217883110045
# 34: Train=0.29021445989608763 Valid=0.33781929850578307
# 35: Train=0.2899612820148468 Valid=0.3317286717891693
# 36: Train=0.2894550210237503 Valid=0.3338024318218231
# 37: Train=0.28927119374275206 Valid=0.330197252035141
# 38: Train=0.2887520456314087 Valid=0.3313221621513367
# 39: Train=0.28859216094017026 Valid=0.3292556893825531
# 40: Train=0.2882219588756561 Valid=0.33037821054458616
# 41: Train=0.28802426159381866 Valid=0.32881850123405454
# 42: Train=0.2875703740119934 Valid=0.32704546093940734
# 43: Train=0.2872398269176483 Valid=0.32814024806022646
# 44: Train=0.28379285216331485 Valid=0.3282224595546722
# 45: Train=0.28321244597434997 Valid=0.32795013427734376
# 46: Train=0.28298839688301086 Valid=0.32458005428314207
# 47: Train=0.28260074973106386 Valid=0.32580947279930117
# 48: Train=0.2823622632026672 Valid=0.3244203519821167
# 49: Train=0.281866073012352 Valid=0.32463327288627625
# 50: Train=0.28165157079696657 Valid=0.32499642491340636
# 51: Train=0.2815285778045654 Valid=0.3237707495689392
# 52: Train=0.2812096863985062 Valid=0.3259221386909485
# 53: Train=0.2809873127937317 Valid=0.32357346415519717
# 54: Train=0.2807951444387436 Valid=0.3236545217037201
# 55: Train=0.2804559528827667 Valid=0.3229672813415527
# 56: Train=0.2804798847436905 Valid=0.32409433484077455
# 57: Train=0.2803128170967102 Valid=0.32374064803123476
# 58: Train=0.2802440708875656 Valid=0.3244177198410034
# 59: Train=0.28004889488220214 Valid=0.3225623273849487
# 60: Train=0.2799291598796845 Valid=0.32203412771224976
# 61: Train=0.2798119020462036 Valid=0.32444232344627383
# 62: Train=0.2798541080951691 Valid=0.32334019780158996
# 63: Train=0.27980893194675444 Valid=0.321593257188797
# 64: Train=0.2794678455591202 Valid=0.32127816557884215
# 65: Train=0.27949790239334105 Valid=0.32261468648910524
# 66: Train=0.27948783576488495 Valid=0.32260825872421267
# 67: Train=0.27952814638614654 Valid=0.3218405246734619
# 68: Train=0.27940734684467317 Valid=0.32175223469734193
# 69: Train=0.27914963483810423 Valid=0.32297269701957704
# 70: Train=0.2791804081201553 Valid=0.3231944167613983
# 71: Train=0.2792457318305969 Valid=0.32264668464660645
# 72: Train=0.2794494324922562 Valid=0.321002151966095
# 73: Train=0.27915910720825193 Valid=0.32476197957992553
# 74: Train=0.2789545947313309 Valid=0.3217117428779602
# 75: Train=0.27906733870506284 Valid=0.3207625663280487
# 76: Train=0.2789719194173813 Valid=0.32191413402557373
# 77: Train=0.2789058530330658 Valid=0.3228002595901489
# 78: Train=0.2788784396648407 Valid=0.32230371475219727
# 79: Train=0.27881810784339905 Valid=0.3218700134754181
# 80: Train=0.2789134335517883 Valid=0.3231001126766205
# 81: Train=0.2788969439268112 Valid=0.32186145067214966
# 82: Train=0.2789268457889557 Valid=0.3213698279857635
# 83: Train=0.27877260982990265 Valid=0.3218639659881592
# 84: Train=0.2786424869298935 Valid=0.3226086950302124
# 85: Train=0.2785511237382889 Valid=0.32246155858039854
# 86: Train=0.27884263277053833 Valid=0.3253799915313721
# 87: Train=0.27873007535934446 Valid=0.32365465998649595
# 88: Train=0.27864927530288697 Valid=0.3213705790042877
# 89: Train=0.27852202296257017 Valid=0.32233689665794374
# 90: Train=0.27856483340263366 Valid=0.32139939308166504
# 91: Train=0.2785582345724106 Valid=0.3203245544433594
# 92: Train=0.27845473229885104 Valid=0.32219347953796384
# 93: Train=0.2788689792156219 Valid=0.3258134412765503
# 94: Train=0.27866053104400634 Valid=0.32473524689674377
# 95: Train=0.2785952973365784 Valid=0.32217692494392397
# 96: Train=0.2784107083082199 Valid=0.3210229706764221
# 97: Train=0.27833219945430754 Valid=0.322593948841095
# 98: Train=0.27904202342033385 Valid=0.3241681635379791
# 99: Train=0.2784603768587112 Valid=0.32207843780517575
# 100: Train=0.2783346354961395 Valid=0.321341472864151
# Loading best model with loss 0.3203245544433594
# Evaluating best BCE model from epoch 90 with loss 0.3203245544433594
# *********************
# Predicting inferno samples
# *********************
# Predicting bce samples
# *********************
# Finished training
# *********************

# %%
importlib.reload(inferno_opendata)
importlib.reload(preproc)
importlib.reload(train)
importlib.reload(plot)
importlib.reload(fit)
importlib.reload(inferno_config)
importlib.reload(stack)
samples = inferno_opendata.run_cmsopen(args, retrain = False, do_fit = True)
# Out:
# *********************
# Fitting INFERNO and binary-cross entropy (BCE) model
# *********************
#
# *********************
# Outpath /home/centos/mount_point/data/test
# *********************
# Summary features and systematics
# *********************
# Features ['aplanarity', 'chargeEta', 'MET_met', 'deltaPhiTauMet']
# All loaded shape syst ['06_jes', 'taue', 'jer']
# Shape systematics ['jes']
# Weight systematics []
# Scale shapes [('jes', 0.06)]
# Signal norms {}
# Background norms {}
# Scale norms None
# *********************
# Loading samples from path /home/centos/mount_point/data/test
# *********************
# Excluding samples used in training
# *********************
# WARNING: Rebinning INFERNO due to zero bins
# *********************
# Create ROOT trees
# Normalization TTJets_bkg 134.10340303520601
# Normalization TTJets_bkg_btag_up 135.9716189713958
# Normalization TTJets_bkg_btag_down 132.16102273109536
# Normalization TTJets_bkg_trigger_up 143.88557950177747
# Normalization TTJets_bkg_trigger_down 122.4773544059986
# Normalization TTJets_bkg_jes_up 143.73616773072973
# Normalization TTJets_bkg_jes_down 121.42311660782973
# Normalization TTJets_bkg_taue_up 139.34421652696145
# Normalization TTJets_bkg_taue_down 126.24503090853688
# Normalization TTJets_bkg_jer_up 131.1264066173969
# Normalization TTJets_bkg_jer_down 136.69119287774876
# Normalization WZJets 63.68725636342331
# Normalization WZJets_btag_up 67.90069100107655
# Normalization WZJets_btag_down 59.432658214292616
# Normalization WZJets_trigger_up 67.84260198172886
# Normalization WZJets_trigger_down 58.131368912624296
# Normalization WZJets_jes_up 70.4341307360625
# Normalization WZJets_jes_down 55.441348132019655
# Normalization WZJets_taue_up 62.8582210399258
# Normalization WZJets_taue_down 61.78838537033156
# Normalization WZJets_jer_up 63.49706201783593
# Normalization WZJets_jer_down 63.50839087651814
# Normalization STJets 30.208598089904672
# Normalization STJets_btag_up 30.79749057818866
# Normalization STJets_btag_down 29.607196450769408
# Normalization STJets_trigger_up 32.3680755275075
# Normalization STJets_trigger_down 27.665253464629775
# Normalization STJets_jes_up 33.263370939570535
# Normalization STJets_jes_down 26.599386111019896
# Normalization STJets_taue_up 30.729174455555878
# Normalization STJets_taue_down 28.82001988364199
# Normalization STJets_jer_up 29.708409086783266
# Normalization STJets_jer_down 30.932922406888746
# Normalization QCD 2690.7227857230937
# Normalization TTJets_signal 348.45252731445083
# Normalization TTJets_signal_btag_up 352.9554949049424
# Normalization TTJets_signal_btag_down 343.7644290330551
# Normalization TTJets_signal_trigger_up 374.33739043789404
# Normalization TTJets_signal_trigger_down 316.7501243963685
# Normalization TTJets_signal_pdf_up 386.60100734026264
# Normalization TTJets_signal_pdf_down 313.5133007015495
# Normalization TTJets_signal_jes_up 383.26979833286873
# Normalization TTJets_signal_jes_down 308.48318067873277
# Normalization TTJets_signal_taue_up 355.0448159528873
# Normalization TTJets_signal_taue_down 331.4043246150461
# Normalization TTJets_signal_jer_up 347.0180218140101
# Normalization TTJets_signal_jer_down 349.7573085438871
# Normalization Data 3323.0
# *********************
# Summary fit args
# *********************
# Fit model signal_only
# Fit norms {}
# Fit shape systematics ['jes']
# Fit asimov True
# Fit data False
# Fit significance True
# Fit float QCD True
# Prune stat error True
# Minos ['mu']
# Scan n steps 200
# *********************
# Fit bce asimov
# INFO - cabinetry.tabulate - yields per channel for pre-fit model prediction:
# ╒═══════════════╤═════════════════╕
# │ sample        │ Signal_region   │
# ╞═══════════════╪═════════════════╡
# │ QCD           │ 2690.72         │
# ├───────────────┼─────────────────┤
# │ STJets        │ 30.21           │
# ├───────────────┼─────────────────┤
# │ TTJets_bkg    │ 134.10          │
# ├───────────────┼─────────────────┤
# │ TTJets_signal │ 348.45          │
# ├───────────────┼─────────────────┤
# │ WZJets        │ 63.69           │
# ├───────────────┼─────────────────┤
# │ total         │ 3267.17 ± 37.39 │
# ├───────────────┼─────────────────┤
# │ data          │ 3267.17         │
# ╘═══════════════╧═════════════════╛
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - MINUIT status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 109.4                      │              Nfcn = 73               │
# │ EDM = 2.08e-15 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │        No Parameters at limit        │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │  Covariance   │     Hesse ok     │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# INFO - cabinetry.fit - running MINOS for mu
# INFO - cabinetry.fit - MINOS results:
# INFO - cabinetry.fit - mu                =  1.0000 -0.1141 +0.1421
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - QCD_norm          =  1.0000 +/- 0.0219
# INFO - cabinetry.fit - mu                =  1.0000 +/- 0.1257
# INFO - cabinetry.fit - TTJets_signal_jes =  0.0000 +/- 0.9594
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# WARNING - cabinetry.histo - Signal_region_Data has empty bins: [1 3]
# WARNING - cabinetry.histo - Signal_region_QCD has empty bins: [1 6 8]
# {'mu': (-0.11408584926867608, 0.14211776074738958)}
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# {'mu': (-0.09535330907817449, 0.09797650229607115)}
# *********************
# Fit inferno asimov
# WARNING - cabinetry.histo - Signal_region_WZJets has empty bins: [1 3 5 6 8]
# WARNING - cabinetry.histo - Signal_region_STJets has empty bins: [1 6]
# WARNING - cabinetry.histo - Signal_region_Data has empty bins: [1 3]
# WARNING - cabinetry.histo - Signal_region_QCD has empty bins: [1 6 8]
# WARNING - cabinetry.histo - Signal_region_WZJets has empty bins: [1 3 5 6 8]
# WARNING - cabinetry.histo - Signal_region_STJets has empty bins: [1 6]
# INFO - cabinetry.tabulate - yields per channel for pre-fit model prediction:
# ╒═══════════════╤═════════════════╕
# │ sample        │ Signal_region   │
# ╞═══════════════╪═════════════════╡
# │ QCD           │ 2690.72         │
# ├───────────────┼─────────────────┤
# │ STJets        │ 30.21           │
# ├───────────────┼─────────────────┤
# │ TTJets_bkg    │ 134.10          │
# ├───────────────┼─────────────────┤
# │ TTJets_signal │ 348.45          │
# ├───────────────┼─────────────────┤
# │ WZJets        │ 63.69           │
# ├───────────────┼─────────────────┤
# │ total         │ 3267.17 ± 37.39 │
# ├───────────────┼─────────────────┤
# │ data          │ 3267.17         │
# ╘═══════════════╧═════════════════╛
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - MINUIT status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 61.8                       │              Nfcn = 74               │
# │ EDM = 6.62e-15 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │        No Parameters at limit        │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │  Covariance   │     Hesse ok     │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# INFO - cabinetry.fit - running MINOS for mu
# INFO - cabinetry.fit - MINOS results:
# INFO - cabinetry.fit - mu                =  1.0000 -0.1026 +0.1120
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - QCD_norm          =  1.0000 +/- 0.0222
# INFO - cabinetry.fit - mu                =  1.0000 +/- 0.1067
# INFO - cabinetry.fit - TTJets_signal_jes =  0.0000 +/- 0.6737
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# {'mu': (-0.10258110239342849, 0.11202672864621088)}
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W VariableMetricBuilder No improvement in line search
# W DavidonErrorUpdator delgam < 0 : first derivatives increasing along search line
# W VariableMetricBuilder No improvement in line search
# {'mu': (-0.09592743634940583, 0.09904986754808677)}
# *****************
# Summary bce asimov
# QCD_norm 1.0 +- 0.022
# mu 1.0 +- 0.126
# TTJets_signal_jes 0.0 +- 0.959
# Minos uncertainty mu -0.11408584926867608 0.14211776074738958
# Correlation matrix
# [[ 1.         -0.16027206 -0.13783009]
#  [-0.16027206  1.         -0.639164  ]
#  [-0.13783009 -0.639164    1.        ]]
# Significance expected 12.327094397310313
# Significance observed 12.327094391091986
# *****************
# *****************
# Summary inferno asimov
# QCD_norm 1.0 +- 0.022
# mu 1.0 +- 0.107
# TTJets_signal_jes 0.0 +- 0.674
# Minos uncertainty mu -0.10258110239342849 0.11202672864621088
# Correlation matrix
# [[ 1.         -0.22812642 -0.18059701]
#  [-0.22812642  1.         -0.40692985]
#  [-0.18059701 -0.40692985  1.        ]]
# Significance expected 12.847903488765446
# Significance observed 12.847903488765446
# *****************

# %%
from hep_model import pval_and_significance

# %%
from scipy.stats import norm, chi2

# %%
lr = 120.
p_val = chi2.sf(lr,1)
significance = norm.ppf(1-p_val)
print("pval", p_val)
print("significance", significance)
print(norm.isf(p_val, 0, 1))
# Out:
# pval 6.326068263677272e-28
# significance inf
# 10.891512484631686
