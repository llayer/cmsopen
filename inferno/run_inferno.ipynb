# %%
import inferno_opendata
import preproc
import importlib
import train
import plot
import fit
import inferno_config
import hep_model
import stack

# %%
importlib.reload(inferno_opendata)
importlib.reload(preproc)
importlib.reload(train)
importlib.reload(plot)
importlib.reload(hep_model)
importlib.reload(inferno_config)
args = inferno_config.args
args["outpath"] = "/home/centos/mount_point/data/test"
args["shape_syst"] = []
args["downsample_factor"] = None

# %%
samples = inferno_opendata.run_cmsopen(args, epochs = 100, do_fit = False)
# Out:
# *********************
# Training INFERNO and binary-cross entropy (BCE) model
# *********************
#
# *********************
# Outpath /home/centos/mount_point/data/test
# *********************
# Summary features and systematics
# *********************
# Features ['aplanarity', 'chargeEta', 'MET_met', 'deltaPhiTauMet']
# All loaded shape syst ['06_jes', 'taue', 'jer']
# Shape systematics []
# Weight systematics []
# Scale shapes [('jes', 0.06)]
# Signal norms {}
# Background norms {}
# Scale norms None
# *********************
# Summary training data
# *********************
# Number of signal training / test events: 20000 23570
# Number of bkg training / test events: 5000 6176
# Use weights True
# Batch size 1000
# x torch.Size([4, 1])
# y tensor([1.])
# w torch.Size([1, 1])
# *********************
# Scaling normalizations of shape systematics
# *********************
# Scaling TTJets_bkg_jes_up from 135.60015823653745 to 143.73616773072973
# Scaling TTJets_bkg_jes_down from 129.17352830620186 to 121.42311660782973
# Scaling WZJets_jes_up from 66.44729314722876 to 70.4341307360625
# Scaling WZJets_jes_down from 58.98015758725496 to 55.441348132019655
# Scaling STJets_jes_up from 31.38053862223635 to 33.263370939570535
# Scaling STJets_jes_down from 28.297219267042443 to 26.599386111019896
# Scaling TTJets_signal_jes_up from 361.5752814461025 to 383.2697983328686
# Scaling TTJets_signal_jes_down from 328.17359646673697 to 308.48318067873277
# *********************
# Summary normalization
# *********************
# Normalization TTJets_bkg 134.10340303520601
# Normalization TTJets_bkg_jes_up 143.73616773072973
# Normalization TTJets_bkg_jes_down 121.42311660782973
# Normalization TTJets_bkg_taue_up 139.34421652696145
# Normalization TTJets_bkg_taue_down 126.24503090853688
# Normalization TTJets_bkg_jer_up 131.1264066173969
# Normalization TTJets_bkg_jer_down 136.69119287774876
# Normalization WZJets 63.68725636342331
# Normalization WZJets_jes_up 70.4341307360625
# Normalization WZJets_jes_down 55.441348132019655
# Normalization WZJets_taue_up 62.8582210399258
# Normalization WZJets_taue_down 61.78838537033156
# Normalization WZJets_jer_up 63.49706201783593
# Normalization WZJets_jer_down 63.50839087651814
# Normalization STJets 30.208598089904672
# Normalization STJets_jes_up 33.263370939570535
# Normalization STJets_jes_down 26.599386111019896
# Normalization STJets_taue_up 30.729174455555878
# Normalization STJets_taue_down 28.82001988364199
# Normalization STJets_jer_up 29.708409086783266
# Normalization STJets_jer_down 30.932922406888746
# Normalization QCD 2690.7227857230937
# Normalization TTJets_signal 348.4525273144509
# Normalization TTJets_signal_jes_up 383.2697983328686
# Normalization TTJets_signal_jes_down 308.48318067873277
# Normalization TTJets_signal_taue_up 355.0448159528873
# Normalization TTJets_signal_taue_down 331.4043246150461
# Normalization TTJets_signal_jer_up 347.01802181401007
# Normalization TTJets_signal_jer_down 349.7573085438872
# Normalization Data 3323.0
# *********************
#
# *********************
# Summary INFERNO model
# *********************
# Learning rate 0.001
# Temperature 0.1
# Neurons 100
# Bins 10
# *********************
# Summary INFERNO callback
# *********************
# b_true 2690.7227857230937
# mu_true 348.4525273144509
# n_shape_systs 0
# n_weight_systs 0
# nshape_alphas 0
# shape idx []
# shape_norm_sigma []
# s_norm_sigma []
# s_norm_idxs []
# b_norm_sigma []
# b_norm_idxs []
# b_rate_param False
# b_rate_param_idx []
# n_alpha 1
# interp_algo default
# use_hist False
# sigmoid delta 200.0
# ignore_loss False
# ignore_shape_norm False
# asymm_shape_norm True
# *********************
# 1: Train=1271.6907568359375 Valid=904.3714742024739
# 2: Train=852.8983251953125 Valid=845.9726867675781
# 3: Train=814.5892919921876 Valid=820.2602010091146
# 4: Train=799.2257446289062 Valid=808.4011006673177
# 5: Train=791.8763256835938 Valid=803.2040222167968
# 6: Train=782.0433422851562 Valid=793.1306396484375
# 7: Train=776.6183862304688 Valid=789.4447713216146
# 8: Train=769.4092211914062 Valid=786.7511535644531
# 9: Train=765.4345654296875 Valid=783.4957458496094
# 10: Train=761.6959594726562 Valid=772.5990112304687
# 11: Train=754.5606787109375 Valid=773.3870849609375
# 12: Train=753.571484375 Valid=773.0731282552083
# 13: Train=751.4341577148438 Valid=774.701816813151
# 14: Train=746.9087744140625 Valid=769.3115865071615
# 15: Train=746.7160546875 Valid=767.5671061197917
# 16: Train=748.9052612304688 Valid=767.0049825032552
# 17: Train=740.8194116210938 Valid=767.848221842448
# 18: Train=740.1092114257813 Valid=767.2937906901042
# 19: Train=739.1212768554688 Valid=762.4787272135417
# 20: Train=735.742314453125 Valid=763.1730651855469
# 21: Train=734.7955981445313 Valid=763.4166483561198
# 22: Train=734.6232373046874 Valid=763.1008463541667
# 23: Train=735.2343676757813 Valid=766.5711669921875
# 24: Train=731.168017578125 Valid=767.046219889323
# 25: Train=732.4759619140625 Valid=767.6034769694011
# 26: Train=735.4328857421875 Valid=761.9958170572917
# 27: Train=732.5988940429687 Valid=764.4700317382812
# 28: Train=727.98546875 Valid=765.2272867838542
# 29: Train=730.0513940429687 Valid=761.6591573079427
# 30: Train=723.7409692382812 Valid=761.7844645182291
# 31: Train=723.7885131835938 Valid=762.6312459309896
# 32: Train=726.4531665039062 Valid=759.3010375976562
# 33: Train=723.3636157226563 Valid=759.1857055664062
# 34: Train=721.5595263671875 Valid=762.3654642740886
# 35: Train=722.9029272460938 Valid=755.6346252441406
# 36: Train=726.5432788085938 Valid=761.8194478352865
# 37: Train=722.2870458984376 Valid=759.9532592773437
# 38: Train=722.054443359375 Valid=759.834403483073
# 39: Train=726.9829809570313 Valid=754.1120320638021
# 40: Train=725.5821484375 Valid=755.6620300292968
# 41: Train=719.9687841796875 Valid=753.4555338541667
# 42: Train=719.443359375 Valid=758.987479654948
# 43: Train=725.0938256835938 Valid=761.2621744791667
# 44: Train=720.122001953125 Valid=752.5037190755208
# 45: Train=711.5726635742187 Valid=763.0662109375
# 46: Train=714.05673828125 Valid=750.9941080729167
# 47: Train=712.661259765625 Valid=745.9240091959635
# 48: Train=720.9576806640625 Valid=748.1637959798177
# 49: Train=710.8572875976563 Valid=740.0698262532552
# 50: Train=705.404990234375 Valid=751.0678405761719
# 51: Train=700.7274609375 Valid=740.6566141764323
# 52: Train=701.8872290039062 Valid=746.8071919759115
# 53: Train=700.0664111328125 Valid=746.4896118164063
# 54: Train=703.1093383789063 Valid=743.2187479654948
# 55: Train=703.9323364257813 Valid=737.057871500651
# 56: Train=704.2488500976563 Valid=745.1916158040365
# 57: Train=699.5499731445312 Valid=735.4537048339844
# 58: Train=695.7203515625 Valid=737.6473124186198
# 59: Train=707.3063842773438 Valid=743.7546651204427
# 60: Train=703.4858203125 Valid=744.8086303710937
# 61: Train=708.2494384765625 Valid=735.2530334472656
# 62: Train=704.96861328125 Valid=736.9508565266927
# 63: Train=698.7434326171875 Valid=739.2151509602865
# 64: Train=699.1113891601562 Valid=739.3354858398437
# 65: Train=699.2578149414062 Valid=739.1838928222656
# 66: Train=694.126181640625 Valid=740.2421630859375
# 67: Train=692.2027490234375 Valid=739.3994201660156
# 68: Train=696.297451171875 Valid=738.9005167643229
# 69: Train=697.8807446289062 Valid=735.6296101888021
# 70: Train=690.6203002929688 Valid=741.6874613444011
# 71: Train=691.8212939453125 Valid=737.3659016927083
# 72: Train=694.0565942382813 Valid=736.980029296875
# 73: Train=697.0215649414063 Valid=738.2074096679687
# 74: Train=699.51572265625 Valid=730.506270345052
# 75: Train=691.2378369140625 Valid=737.4147745768229
# 76: Train=697.4588354492188 Valid=742.9168986002604
# 77: Train=696.3782666015625 Valid=737.2248575846354
# 78: Train=694.8577905273437 Valid=739.8518371582031
# 79: Train=698.3214453125 Valid=743.5583516438802
# 80: Train=693.5543115234375 Valid=727.4814982096354
# 81: Train=691.8665551757813 Valid=736.1914388020833
# 82: Train=689.9990991210938 Valid=738.3620381673177
# 83: Train=693.7084375 Valid=737.3569315592448
# 84: Train=687.237724609375 Valid=741.0459025065104
# 85: Train=687.3090649414063 Valid=743.7465515136719
# 86: Train=692.7450708007813 Valid=739.9957580566406
# 87: Train=694.6226928710937 Valid=747.094394938151
# 88: Train=692.702578125 Valid=737.4783671061198
# 89: Train=693.7656640625 Valid=733.1315714518229
# 90: Train=682.406337890625 Valid=741.2675699869792
# 91: Train=698.40892578125 Valid=738.4324991861979
# 92: Train=694.3740185546875 Valid=741.3457682291667
# 93: Train=689.2201318359375 Valid=742.9304606119791
# 94: Train=691.0715405273437 Valid=731.9656962076823
# 95: Train=686.885234375 Valid=742.1494160970052
# 96: Train=688.1812939453125 Valid=734.9300964355468
# 97: Train=684.2366333007812 Valid=738.5515299479167
# 98: Train=683.6063891601563 Valid=731.027901204427
# 99: Train=687.6785205078126 Valid=733.5294250488281
# 100: Train=694.9311645507812 Valid=730.6219258626302
# Loading best model with loss 727.4814982096354
# Evaluating best INFERNO model from epoch 79 with loss 727.4814982096354
# *********************
# Summary BCE model
# *********************
# Learning rate 0.001
# Neurons 20
# *********************
# Summary INFERNO callback
# *********************
# b_true 2690.7227857230937
# mu_true 348.4525273144509
# n_shape_systs 0
# n_weight_systs 0
# nshape_alphas 0
# shape idx []
# shape_norm_sigma []
# s_norm_sigma []
# s_norm_idxs []
# b_norm_sigma []
# b_norm_idxs []
# b_rate_param False
# b_rate_param_idx []
# n_alpha 1
# interp_algo default
# use_hist True
# sigmoid delta 200.0
# ignore_loss True
# ignore_shape_norm False
# asymm_shape_norm True
# *********************
# 1: Train=0.6973107409477234 Valid=0.665134342511495
# 2: Train=0.6364822769165039 Valid=0.6059841732184092
# 3: Train=0.574252016544342 Valid=0.5450778206189474
# 4: Train=0.5129695224761963 Valid=0.48952299257119497
# 5: Train=0.46153502821922304 Valid=0.4479171802600225
# 6: Train=0.4253492033481598 Valid=0.42001737356185914
# 7: Train=0.4008397316932678 Valid=0.4002937803665797
# 8: Train=0.3833983242511749 Valid=0.3858403225739797
# 9: Train=0.3698991703987122 Valid=0.3739950229724248
# 10: Train=0.3586627781391144 Valid=0.3688396543264389
# 11: Train=0.34867738246917723 Valid=0.35944236715634664
# 12: Train=0.3392136287689209 Valid=0.3498904585838318
# 13: Train=0.3303299081325531 Valid=0.3455594539642334
# 14: Train=0.3227060270309448 Valid=0.3420066108306249
# 15: Train=0.3163740158081055 Valid=0.33585549096266426
# 16: Train=0.31166036367416383 Valid=0.33209894597530365
# 17: Train=0.3081053853034973 Valid=0.32911460697650907
# 18: Train=0.3054002916812897 Valid=0.32728768487771354
# 19: Train=0.30365712285041807 Valid=0.32574936250845593
# 20: Train=0.30202658534049986 Valid=0.32566185494263966
# 21: Train=0.3008489322662353 Valid=0.32356056769688923
# 22: Train=0.2999264991283417 Valid=0.3198843657970428
# 23: Train=0.29922025799751284 Valid=0.31978432536125184
# 24: Train=0.2986834490299225 Valid=0.3161092072725296
# 25: Train=0.29794845342636106 Valid=0.3155361255009969
# 26: Train=0.2975313711166382 Valid=0.31498590111732483
# 27: Train=0.2969605028629303 Valid=0.31432141959667204
# 28: Train=0.29679136753082275 Valid=0.31400079329808556
# 29: Train=0.2963728046417236 Valid=0.31336937844753265
# 30: Train=0.29593743801116945 Valid=0.3139576236406962
# 31: Train=0.29569191455841065 Valid=0.3076549897591273
# 32: Train=0.2953394788503647 Valid=0.3070464620987574
# 33: Train=0.29500181794166563 Valid=0.30697129567464193
# 34: Train=0.29476085424423215 Valid=0.3063751588265101
# 35: Train=0.29443823218345644 Valid=0.3060743361711502
# 36: Train=0.29443087577819826 Valid=0.3059512843688329
# 37: Train=0.29414775490760803 Valid=0.30578024685382843
# 38: Train=0.2938845717906952 Valid=0.30534362892309824
# 39: Train=0.2936959803104401 Valid=0.30484577814737956
# 40: Train=0.29363289833068845 Valid=0.30465654134750364
# 41: Train=0.2933423936367035 Valid=0.3046169996261597
# 42: Train=0.29315776586532594 Valid=0.30422615508238476
# 43: Train=0.2928821611404419 Valid=0.3044403910636902
# 44: Train=0.292743501663208 Valid=0.30383634865283965
# 45: Train=0.2927014362812042 Valid=0.30355130036671957
# 46: Train=0.2925223481655121 Valid=0.3032393505175908
# 47: Train=0.2926304018497467 Valid=0.30381019214789073
# 48: Train=0.29219058096408845 Valid=0.30298151870568596
# 49: Train=0.29219135761260984 Valid=0.30294911166032157
# 50: Train=0.2920228004455566 Valid=0.30286304553349813
# 51: Train=0.29197042107582094 Valid=0.3027009765307109
# 52: Train=0.29184720158576966 Valid=0.3025855173667272
# 53: Train=0.29175254702568054 Valid=0.3023903767267863
# 54: Train=0.29174984991550446 Valid=0.3024045358101527
# 55: Train=0.2915982294082642 Valid=0.3024131904045741
# 56: Train=0.29141669034957884 Valid=0.3027776390314102
# 57: Train=0.29137718558311465 Valid=0.3021276245514552
# 58: Train=0.29129848957061766 Valid=0.302071213722229
# 59: Train=0.2914526450634003 Valid=0.30175885260105134
# 60: Train=0.2912071394920349 Valid=0.30230320195357
# 61: Train=0.29114101469516757 Valid=0.30198030869166054
# 62: Train=0.29107792615890504 Valid=0.3022119174400965
# 63: Train=0.29105573773384097 Valid=0.3023388147354126
# 64: Train=0.290997331738472 Valid=0.3016578326622645
# 65: Train=0.2910223400592804 Valid=0.30222591360410056
# 66: Train=0.29091215968132017 Valid=0.3024862100680669
# 67: Train=0.2908385020494461 Valid=0.30161086221536
# 68: Train=0.2908194941282272 Valid=0.3016516357660294
# 69: Train=0.29078917264938353 Valid=0.3024643709262212
# 70: Train=0.29060834646224976 Valid=0.30163531402746835
# 71: Train=0.29065200328826907 Valid=0.30232734282811485
# 72: Train=0.2906017816066742 Valid=0.3017694185177485
# 73: Train=0.29056616127491 Valid=0.3014925489823023
# 74: Train=0.29047565698623656 Valid=0.30203157862027485
# 75: Train=0.290513414144516 Valid=0.30137181182702383
# 76: Train=0.2905703067779541 Valid=0.3016219367583593
# 77: Train=0.2905727255344391 Valid=0.3016872922579447
# 78: Train=0.2904209613800049 Valid=0.3016136129697164
# 79: Train=0.2907355642318726 Valid=0.3019585202137629
# 80: Train=0.29040414571762085 Valid=0.30196196436882017
# 81: Train=0.2903336644172668 Valid=0.30151934623718263
# 82: Train=0.2903368937969208 Valid=0.30146539906660713
# 83: Train=0.2902474939823151 Valid=0.30157011151313784
# 84: Train=0.2901925015449524 Valid=0.30161004364490507
# 85: Train=0.29019385933876035 Valid=0.3012646238009135
# 86: Train=0.29024808406829833 Valid=0.30160507261753083
# 87: Train=0.29009965538978577 Valid=0.30157318115234377
# 88: Train=0.2901642668247223 Valid=0.30146040121714274
# 89: Train=0.29031564950942995 Valid=0.3014417737722397
# 90: Train=0.2902471387386322 Valid=0.30165979961554207
# 91: Train=0.2901312327384949 Valid=0.3014358192682266
# 92: Train=0.2900766897201538 Valid=0.30107464691003166
# 93: Train=0.2899700605869293 Valid=0.3012799690167109
# 94: Train=0.29002437472343445 Valid=0.3013793587684631
# 95: Train=0.2901294219493866 Valid=0.3010950952768326
# 96: Train=0.289880730509758 Valid=0.30107508301734925
# 97: Train=0.28989681601524353 Valid=0.3009253978729248
# 98: Train=0.28999152660369876 Valid=0.30108863015969595
# 99: Train=0.2899407583475113 Valid=0.3010268161694209
# 100: Train=0.29002371191978454 Valid=0.3014194866021474
# Loading best model with loss 0.3009253978729248
# Evaluating best BCE model from epoch 96 with loss 0.3009253978729248
# *********************
# Predicting inferno samples
# *********************
# Predicting bce samples
# *********************
# Finished training
# *********************

# %%
importlib.reload(inferno_opendata)
importlib.reload(preproc)
importlib.reload(train)
importlib.reload(plot)
importlib.reload(fit)
importlib.reload(inferno_config)
importlib.reload(stack)
args["rebin_hist"] = 20
samples = inferno_opendata.run_cmsopen(args, retrain = False, do_fit = True)
# Out:
# *********************
# Fitting INFERNO and binary-cross entropy (BCE) model
# *********************
#
# *********************
# Outpath /home/centos/mount_point/data/test
# *********************
# Summary features and systematics
# *********************
# Features ['aplanarity', 'chargeEta', 'MET_met', 'deltaPhiTauMet']
# All loaded shape syst ['06_jes', 'taue', 'jer']
# Shape systematics []
# Weight systematics []
# Scale shapes [('jes', 0.06)]
# Signal norms {}
# Background norms {}
# Scale norms None
# *********************
# Loading samples from path /home/centos/mount_point/data/test
# *********************
# Excluding samples used in training
# *********************
# WARNING: Rebinning INFERNO due to zero bins
# *********************
# Create ROOT trees
# Normalization TTJets_bkg 134.10340303520601
# Normalization TTJets_bkg_btag_up 135.9716189713958
# Normalization TTJets_bkg_btag_down 132.16102273109536
# Normalization TTJets_bkg_trigger_up 143.88557950177747
# Normalization TTJets_bkg_trigger_down 122.4773544059986
# Normalization TTJets_bkg_jes_up 143.73616773072973
# Normalization TTJets_bkg_jes_down 121.42311660782973
# Normalization TTJets_bkg_taue_up 139.34421652696145
# Normalization TTJets_bkg_taue_down 126.24503090853688
# Normalization TTJets_bkg_jer_up 131.1264066173969
# Normalization TTJets_bkg_jer_down 136.69119287774876
# Normalization WZJets 63.68725636342331
# Normalization WZJets_btag_up 67.90069100107655
# Normalization WZJets_btag_down 59.432658214292616
# Normalization WZJets_trigger_up 67.84260198172886
# Normalization WZJets_trigger_down 58.131368912624296
# Normalization WZJets_jes_up 70.4341307360625
# Normalization WZJets_jes_down 55.441348132019655
# Normalization WZJets_taue_up 62.8582210399258
# Normalization WZJets_taue_down 61.78838537033156
# Normalization WZJets_jer_up 63.49706201783593
# Normalization WZJets_jer_down 63.50839087651814
# Normalization STJets 30.208598089904672
# Normalization STJets_btag_up 30.79749057818866
# Normalization STJets_btag_down 29.607196450769408
# Normalization STJets_trigger_up 32.3680755275075
# Normalization STJets_trigger_down 27.665253464629775
# Normalization STJets_jes_up 33.263370939570535
# Normalization STJets_jes_down 26.599386111019896
# Normalization STJets_taue_up 30.729174455555878
# Normalization STJets_taue_down 28.82001988364199
# Normalization STJets_jer_up 29.708409086783266
# Normalization STJets_jer_down 30.932922406888746
# Normalization QCD 2690.7227857230937
# Normalization TTJets_signal 348.4525273144509
# Normalization TTJets_signal_btag_up 352.9135891743315
# Normalization TTJets_signal_btag_down 343.8004749928058
# Normalization TTJets_signal_trigger_up 373.56494855367856
# Normalization TTJets_signal_trigger_down 318.7811466884071
# Normalization TTJets_signal_pdf_up 387.3315346000748
# Normalization TTJets_signal_pdf_down 312.9332645811345
# Normalization TTJets_signal_jes_up 383.26979833286856
# Normalization TTJets_signal_jes_down 308.48318067873277
# Normalization TTJets_signal_taue_up 355.0448159528873
# Normalization TTJets_signal_taue_down 331.4043246150461
# Normalization TTJets_signal_jer_up 347.01802181401007
# WARNING - cabinetry.histo - Signal_region_WZJets has empty bins: [0 6]
# WARNING - cabinetry.histo - Signal_region_WZJets has empty bins: [0 6]
# Normalization TTJets_signal_jer_down 349.75730854388723
# Normalization Data 3323.0
# *********************
# Summary fit args
# *********************
# Fit model signal_only
# Fit norms {}
# Fit shape systematics []
# Fit asimov True
# Fit data False
# Fit significance True
# Fit float QCD True
# Prune stat error True
# Minos ['mu']
# Scan n steps 200
# *********************
# Fit bce asimov
# INFO - cabinetry.tabulate - yields per channel for pre-fit model prediction:
# ╒═══════════════╤═════════════════╕
# │ sample        │ Signal_region   │
# ╞═══════════════╪═════════════════╡
# │ QCD           │ 2690.72         │
# ├───────────────┼─────────────────┤
# │ STJets        │ 30.21           │
# ├───────────────┼─────────────────┤
# │ TTJets_bkg    │ 134.10          │
# ├───────────────┼─────────────────┤
# │ TTJets_signal │ 348.45          │
# ├───────────────┼─────────────────┤
# │ WZJets        │ 63.69           │
# ├───────────────┼─────────────────┤
# │ total         │ 3267.17 ± 0.00  │
# ├───────────────┼─────────────────┤
# │ data          │ 3267.17         │
# ╘═══════════════╧═════════════════╛
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - MINUIT status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 137.5                      │              Nfcn = 38               │
# │ EDM = 4.28e-15 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │        No Parameters at limit        │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │  Covariance   │     Hesse ok     │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# INFO - cabinetry.fit - running MINOS for mu
# INFO - cabinetry.fit - MINOS results:
# INFO - cabinetry.fit - mu       =  1.0000 -0.0920 +0.0947
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - QCD_norm =  1.0000 +/- 0.0215
# INFO - cabinetry.fit - mu       =  1.0000 +/- 0.0934
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder No improvement in line search
# {'mu': (-0.09204099313860228, 0.09469638227321733)}
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder No improvement in line search
# {'mu': (-0.09204099313860228, 0.09469638227321733)}
# *********************
# Fit inferno asimov
# INFO - cabinetry.tabulate - yields per channel for pre-fit model prediction:
# ╒═══════════════╤═════════════════╕
# │ sample        │ Signal_region   │
# ╞═══════════════╪═════════════════╡
# │ QCD           │ 2690.72         │
# ├───────────────┼─────────────────┤
# │ STJets        │ 30.21           │
# ├───────────────┼─────────────────┤
# │ TTJets_bkg    │ 134.10          │
# ├───────────────┼─────────────────┤
# │ TTJets_signal │ 348.45          │
# ├───────────────┼─────────────────┤
# │ WZJets        │ 63.69           │
# ├───────────────┼─────────────────┤
# │ total         │ 3267.17 ± 0.00  │
# ├───────────────┼─────────────────┤
# │ data          │ 3267.17         │
# ╘═══════════════╧═════════════════╛
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - MINUIT status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 58.83                      │              Nfcn = 38               │
# │ EDM = 1.3e-14 (Goal: 0.0002)     │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │        No Parameters at limit        │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │ Below EDM threshold (goal x 10)  │           Below call limit           │
# ├───────────────┬──────────────────┼───────────┬─────────────┬────────────┤
# │  Covariance   │     Hesse ok     │ Accurate  │  Pos. def.  │ Not forced │
# └───────────────┴──────────────────┴───────────┴─────────────┴────────────┘
# INFO - cabinetry.fit - running MINOS for mu
# INFO - cabinetry.fit - MINOS results:
# INFO - cabinetry.fit - mu       =  1.0000 -0.0916 +0.0945
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - QCD_norm =  1.0000 +/- 0.0215
# INFO - cabinetry.fit - mu       =  1.0000 +/- 0.0930
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder No improvement in line search
# {'mu': (-0.09160323521220601, 0.09446849295295463)}
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder No improvement in line search
# W VariableMetricBuilder No improvement in line search
# {'mu': (-0.09160323521220601, 0.09446849295295463)}
# *****************
# Summary bce asimov
# QCD_norm 1.0 +- 0.021
# mu 1.0 +- 0.093
# Minos uncertainty mu -0.09204099313860228 0.09469638227321733
# Correlation matrix
# [[ 1.         -0.30283145]
#  [-0.30283145  1.        ]]
# Significance expected 13.048223069993048
# Significance observed 13.04822307937234
# *****************
# *****************
# Summary inferno asimov
# QCD_norm 1.0 +- 0.021
# mu 1.0 +- 0.093
# Minos uncertainty mu -0.09160323521220601 0.09446849295295463
# Correlation matrix
# [[ 1.         -0.30189856]
#  [-0.30189856  1.        ]]
# Significance expected 13.448262900525956
# Significance observed 13.448262905602954
# *****************

# %%
from hep_model import pval_and_significance

# %%
from scipy.stats import norm, chi2

# %%
lr = 120.
p_val = chi2.sf(lr,1)
significance = norm.ppf(1-p_val)
print("pval", p_val)
print("significance", significance)
print(norm.isf(p_val, 0, 1))
# Out:
# pval 6.326068263677272e-28
# significance inf
# 10.891512484631686
