# %%
import inferno_opendata
#import preproc
#import importlib
#import train
#import plot
#import fit
import inferno_config
#import hep_model
#import stack

# %%
#importlib.reload(inferno_opendata)
#importlib.reload(preproc)
#importlib.reload(train)
#importlib.reload(plot)
#importlib.reload(hep_model)
#importlib.reload(inferno_config)
args = inferno_config.args
args["outpath"] = "/home/centos/mount_point/data/test"
args["temperature"] = 0.5
args["bins"] = 15
args["downsample_factor"] = None

# %%
samples = inferno_opendata.run_cmsopen(args, epochs = 2, do_fit = False)
# Out:
# *********************
# Training INFERNO and binary-cross entropy (BCE) model
# *********************
#
# *********************
# Outpath /home/centos/mount_point/data/test
# *********************
# Summary features and systematics
# *********************
# Features ['aplanarity', 'chargeEta', 'MET_met', 'deltaPhiTauMet', 'mt', 'mTauJet', 'ht', 'sphericity']
# All loaded shape syst ['09_jes', 'taue', 'jer']
# Shape systematics ['jes']
# Weight systematics []
# Scale shapes None
# Signal norms {}
# Background norms {}
# Scale norms None
# ['MET_met', 'event', 'run', 'luminosityBlock', 'HLT_QuadJet40_IsoPFTau40', 'HLT_QuadJet45_IsoPFTau45', 'PV_npvs', 'genEvent_tmeme', 'norm', 'norm_up', 'norm_down', 'trigger_weight', 'trigger_weight_up', 'trigger_weight_down', 'trigger_is40', 'isSignal', 'isBkg', 'btag_weight1', 'btag_weight1_up', 'btag_weight1_down', 'btag_weight2', 'btag_weight2_up', 'btag_weight2_down', 'h', 'ht', 'h_jet', 'ht_jet', 'chargeEta', 'mTauJet', 'mt', 'deltaPhiTauMet', 'nJets', 'aplanarity', 'sphericity', 'train_flag', 'label', 'bdt', 'trigger_jet_up', 'trigger_tau_up', 'trigger_jet_down', 'trigger_tau_down', 'trigger', 'trigger_up', 'trigger_down', 'weight_trigger_up', 'weight_trigger_down', 'weight', 'weight_btag_up', 'btag_up', 'weight_btag_down', 'btag_down', 'weight_trigger_jet_up', 'weight_trigger_jet_down', 'weight_trigger_tau_up', 'weight_trigger_tau_down', 'pdf', 'weight_pdf_0_up', 'weight_pdf_0_down', 'weight_pdf_1_up', 'weight_pdf_1_down', 'weight_pdf_2_up', 'weight_pdf_2_down', 'weight_pdf_3_up', 'weight_pdf_3_down', 'weight_pdf_4_up', 'weight_pdf_4_down', 'weight_pdf_5_up', 'weight_pdf_5_down', 'weight_pdf_6_up', 'weight_pdf_6_down', 'weight_pdf_7_up', 'weight_pdf_7_down', 'weight_pdf_8_up', 'weight_pdf_8_down', 'weight_pdf_9_up', 'weight_pdf_9_down', 'weight_pdf_10_up', 'weight_pdf_10_down', 'weight_pdf_11_up', 'weight_pdf_11_down', 'weight_pdf_12_up', 'weight_pdf_12_down', 'weight_pdf_13_up', 'weight_pdf_13_down', 'weight_pdf_14_up', 'weight_pdf_14_down', 'weight_pdf_15_up', 'weight_pdf_15_down', 'weight_pdf_16_up', 'weight_pdf_16_down', 'weight_pdf_17_up', 'weight_pdf_17_down', 'weight_pdf_18_up', 'weight_pdf_18_down', 'weight_pdf_19_up', 'weight_pdf_19_down', 'weight_pdf_20_up', 'weight_pdf_20_down', 'weight_pdf_21_up', 'weight_pdf_21_down', 'pdf_up', 'pdf_down']
# *********************
# Summary training data
# *********************
# RS for split: 11
# Number of signal training / test events: 20000 23570
# Number of bkg training / test events: 5000 6176
# Use weights True
# Batch size 1000
# x torch.Size([8, 3])
# y tensor([1.])
# w torch.Size([1, 3])
# *********************
# Summary normalization
# *********************
# Normalization TTJets_bkg 134.10340303520601
# Normalization TTJets_bkg_jes_up 135.54526075965
# Normalization TTJets_bkg_jes_down 126.12018182170266
# Normalization TTJets_bkg_taue_up 139.34421652696145
# Normalization TTJets_bkg_taue_down 126.24503090853688
# Normalization TTJets_bkg_jer_up 131.1264066173969
# Normalization TTJets_bkg_jer_down 136.69119287774876
# Normalization WZJets 63.68725636342331
# Normalization WZJets_jes_up 67.45689406939978
# Normalization WZJets_jes_down 57.2630583226196
# Normalization WZJets_taue_up 62.8582210399258
# Normalization WZJets_taue_down 61.78838537033156
# Normalization WZJets_jer_up 63.49706201783593
# Normalization WZJets_jer_down 63.50839087651814
# Normalization STJets 30.208598089904672
# Normalization STJets_jes_up 31.718288056260832
# Normalization STJets_jes_down 27.408850809569614
# Normalization STJets_taue_up 30.729174455555878
# Normalization STJets_taue_down 28.82001988364199
# Normalization STJets_jer_up 29.708409086783266
# Normalization STJets_jer_down 30.932922406888746
# Normalization QCD 2690.7227857230937
# Normalization TTJets_signal 348.4525273144509
# Normalization TTJets_signal_jes_up 364.09891949769445
# Normalization TTJets_signal_jes_down 317.84763594488237
# Normalization TTJets_signal_taue_up 355.0448159528873
# Normalization TTJets_signal_taue_down 331.4043246150461
# Normalization TTJets_signal_jer_up 347.01802181401007
# Normalization TTJets_signal_jer_down 349.7573085438872
# Normalization Data 3323.0
# *********************
#
# *********************
# Summary INFERNO model
# *********************
# Learning rate 0.001
# Temperature 0.5
# Neurons 100
# Bins 10
# [1] []
# [(0.9121691221313771, 1.0449025073912692)] []
# *********************
# Summary INFERNO callback
# *********************
# b_true 2690.7227857230937
# mu_true 348.4525273144509
# n_shape_systs 1
# n_weight_systs 0
# nshape_alphas 1
# shape idx [1]
# shape_norm_sigma [(0.9121691221313771, 1.0449025073912692)]
# s_norm_sigma []
# s_norm_idxs []
# b_norm_sigma []
# b_norm_idxs []
# b_rate_param False
# b_rate_param_idx []
# n_alpha 2
# interp_algo default
# use_hist False
# sigmoid delta 200.0
# ignore_loss False
# ignore_shape_norm False
# asymm_shape_norm True
# store signiificance False
# *********************
# 1: Train=2375.799375 Valid=1200.7108976944633
# 2: Train=995.1239038085937 Valid=893.7547050144361
# Loading best model with loss 893.7547050144361
# Evaluating best INFERNO model from epoch 1 with loss 893.7547050144361
# *********************
# Summary BCE model
# *********************
# Learning rate 0.001
# Neurons 20
# Bins 10
# [1] []
# [(0.9121691221313771, 1.0449025073912692)] []
# *********************
# Summary INFERNO callback
# *********************
# b_true 2690.7227857230937
# mu_true 348.4525273144509
# n_shape_systs 1
# n_weight_systs 0
# nshape_alphas 1
# shape idx [1]
# shape_norm_sigma [(0.9121691221313771, 1.0449025073912692)]
# s_norm_sigma []
# s_norm_idxs []
# b_norm_sigma []
# b_norm_idxs []
# b_rate_param False
# b_rate_param_idx []
# n_alpha 2
# interp_algo default
# use_hist True
# sigmoid delta 200.0
# ignore_loss True
# ignore_shape_norm False
# asymm_shape_norm True
# store signiificance False
# *********************
# 1: Train=0.6642485094070435 Valid=0.634863397349482
# 2: Train=0.5794407415390015 Valid=0.573695965435194
# Loading best model with loss 0.573695965435194
# Evaluating best BCE model from epoch 1 with loss 0.573695965435194
# *********************
# Predicting inferno samples
# *********************
# Predicting bce samples
# *********************
# Finished training
# *********************

# %%
#importlib.reload(inferno_opendata)
#importlib.reload(preproc)
#importlib.reload(train)
#importlib.reload(plot)
#importlib.reload(fit)
#importlib.reload(inferno_config)
#importlib.reload(stack)
samples = inferno_opendata.run_cmsopen(args, retrain = False, do_fit = True)
# Out:
# *********************
# Fitting INFERNO and binary-cross entropy (BCE) model
# *********************
#
# *********************
# Outpath /home/centos/mount_point/data/test
# *********************
# Summary features and systematics
# *********************
# Features ['aplanarity', 'chargeEta', 'MET_met', 'deltaPhiTauMet', 'mt', 'mTauJet', 'ht', 'sphericity']
# All loaded shape syst ['09_jes', 'taue', 'jer']
# Shape systematics ['jes']
# Weight systematics []
# Scale shapes None
# Signal norms {}
# Background norms {}
# Scale norms None
# *********************
# Loading samples from path /home/centos/mount_point/data/test
# ['TTJets_bkg', 'TTJets_bkg_jes_up', 'TTJets_bkg_jes_down', 'TTJets_bkg_jer_up', 'TTJets_bkg_jer_down', 'TTJets_bkg_taue_up', 'TTJets_bkg_taue_down', 'WZJets', 'WZJets_jes_up', 'WZJets_jes_down', 'WZJets_jer_up', 'WZJets_jer_down', 'WZJets_taue_up', 'WZJets_taue_down', 'STJets', 'STJets_jes_up', 'STJets_jes_down', 'STJets_jer_up', 'STJets_jer_down', 'STJets_taue_up', 'STJets_taue_down', 'QCD', 'TTJets_signal', 'TTJets_signal_jes_up', 'TTJets_signal_jes_down', 'TTJets_signal_jer_up', 'TTJets_signal_jer_down', 'TTJets_signal_taue_up', 'TTJets_signal_taue_down', 'Data']
# ['MET_met', 'event', 'run', 'luminosityBlock', 'HLT_QuadJet40_IsoPFTau40', 'HLT_QuadJet45_IsoPFTau45', 'PV_npvs', 'genEvent_tmeme', 'norm', 'norm_up', 'norm_down', 'trigger_weight', 'trigger_weight_up', 'trigger_weight_down', 'trigger_is40', 'isSignal', 'isBkg', 'btag_weight1', 'btag_weight1_up', 'btag_weight1_down', 'btag_weight2', 'btag_weight2_up', 'btag_weight2_down', 'h', 'ht', 'h_jet', 'ht_jet', 'chargeEta', 'mTauJet', 'mt', 'deltaPhiTauMet', 'nJets', 'aplanarity', 'sphericity', 'train_flag', 'label', 'bdt', 'trigger_jet_up', 'trigger_tau_up', 'trigger_jet_down', 'trigger_tau_down', 'trigger', 'trigger_up', 'trigger_down', 'weight_trigger_up', 'weight_trigger_down', 'weight', 'weight_btag_up', 'btag_up', 'weight_btag_down', 'btag_down', 'weight_trigger_jet_up', 'weight_trigger_jet_down', 'weight_trigger_tau_up', 'weight_trigger_tau_down', 'pdf', 'weight_pdf_0_up', 'weight_pdf_0_down', 'weight_pdf_1_up', 'weight_pdf_1_down', 'weight_pdf_2_up', 'weight_pdf_2_down', 'weight_pdf_3_up', 'weight_pdf_3_down', 'weight_pdf_4_up', 'weight_pdf_4_down', 'weight_pdf_5_up', 'weight_pdf_5_down', 'weight_pdf_6_up', 'weight_pdf_6_down', 'weight_pdf_7_up', 'weight_pdf_7_down', 'weight_pdf_8_up', 'weight_pdf_8_down', 'weight_pdf_9_up', 'weight_pdf_9_down', 'weight_pdf_10_up', 'weight_pdf_10_down', 'weight_pdf_11_up', 'weight_pdf_11_down', 'weight_pdf_12_up', 'weight_pdf_12_down', 'weight_pdf_13_up', 'weight_pdf_13_down', 'weight_pdf_14_up', 'weight_pdf_14_down', 'weight_pdf_15_up', 'weight_pdf_15_down', 'weight_pdf_16_up', 'weight_pdf_16_down', 'weight_pdf_17_up', 'weight_pdf_17_down', 'weight_pdf_18_up', 'weight_pdf_18_down', 'weight_pdf_19_up', 'weight_pdf_19_down', 'weight_pdf_20_up', 'weight_pdf_20_down', 'weight_pdf_21_up', 'weight_pdf_21_down', 'pdf_up', 'pdf_down', 'weight_pdf_up', 'weight_pdf_down', 'event_id', 'is_train', 'inferno', 'bce']
# *********************
# Excluding samples used in training
# *********************
# WARNING: Rebinning INFERNO due to zero bins
# *********************
# Create ROOT trees
# WARNING - cabinetry.histo - Signal_region_WZJets has empty bins: [4]
# WARNING - cabinetry.histo - Signal_region_WZJets has empty bins: [4]
# *********************
# Summary fit args
# *********************
# Fit model signal_only
# Fit norms {}
# Fit shape systematics ['jes']
# Fit asimov True
# Fit data False
# Fit significance True
# Fit float QCD True
# Prune stat error True
# Minos ['mu']
# Scan n steps 200
# *********************
# Fit bce asimov

# %%
from hep_model import pval_and_significance

# %%
from scipy.stats import norm, chi2

# %%
lr = 120.
p_val = chi2.sf(lr,1)
significance = norm.ppf(1-p_val)
print("pval", p_val)
print("significance", significance)
print(norm.isf(p_val, 0, 1))
# Out:
# pval 6.326068263677272e-28
# significance inf
# 10.891512484631686
