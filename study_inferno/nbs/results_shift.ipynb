# %%
import ROOT
from array import array
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.24/00

# %%
ROOT.gStyle.SetOptStat(0)

def get_graph(file_path):

    r_obs = array('d',[])
    nll_obs = array('d',[])
    zeros = array('d',[])

    #rootfile = "higgsCombineTest.MultiDimFit.mH120.root"
    rootfile = file_path

    f_obs = ROOT.TFile(rootfile,"READ")
    t_obs = f_obs.Get("limit")
    for i in range(1,t_obs.GetEntries()):
        t_obs.GetEntry(i)
        r_obs.append(t_obs.r)
        nll_obs.append(2.0*t_obs.deltaNLL)
        zeros.append(0.0)

    """
    v_r_obs = ROOT.TVectorD(len(r_obs),r_obs)
    v_nll_obs = ROOT.TVectorD(len(nll_obs),nll_obs)
    v_zeros = ROOT.TVectorD(len(zeros),zeros)

    gr_obs = ROOT.TGraphAsymmErrors(v_r_obs,v_nll_obs,v_zeros,v_zeros,v_zeros,v_zeros)

    return gr_obs, r_obs
    """
    
    return np.array(r_obs), np.array(nll_obs)

# %% [markdown]
# ## Shift

# %%
nll_bce = []
nll_inferno_analytical = []
nll_inferno_approx = []
for i in range(9):
    
    file_path = "/eos/user/l/llayer/cmsopen/columnar/note_v0/combine/inferno_systematic6/Fit/bce_shift_" + str(i) + \
                 "/fit/syst/higgsCombineTest.MultiDimFit.mH120.root"
    nll_bce.append( get_graph(file_path) )
    file_path = "/eos/user/l/llayer/cmsopen/columnar/note_v0/combine/inferno_systematic6/Fit/inferno_shift_analytical_" + str(i) + \
                 "/fit/syst/higgsCombineTest.MultiDimFit.mH120.root"
    nll_inferno_analytical.append( get_graph(file_path) )
    file_path = "/eos/user/l/llayer/cmsopen/columnar/note_v0/combine/inferno_systematic6/Fit/inferno_shift_approx_" + str(i) + \
                 "/fit/syst/higgsCombineTest.MultiDimFit.mH120.root"
    nll_inferno_approx.append( get_graph(file_path) )
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-27-442bdb37297c> in <module>
#       6     file_path = "/eos/user/l/llayer/cmsopen/columnar/note_v0/combine/inferno_systematic6/Fit/bce_shift_" + str(i) + \
#       7                  "/fit/syst/higgsCombineTest.MultiDimFit.mH120.root"
# ----> 8     nll_bce.append( get_graph(file_path) )
#       9     file_path = "/eos/user/l/llayer/cmsopen/columnar/note_v0/combine/inferno_systematic6/Fit/inferno_shift_analytical_" + str(i) + \
#      10                  "/fit/syst/higgsCombineTest.MultiDimFit.mH120.root"
#
# <ipython-input-2-743b0301d82d> in get_graph(file_path)
#      10     rootfile = file_path
#      11
# ---> 12     f_obs = ROOT.TFile(rootfile,"READ")
#      13     t_obs = f_obs.Get("limit")
#      14     for i in range(1,t_obs.GetEntries()):
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_100/x86_64-centos7-gcc8-opt/lib/ROOT/pythonization/_tfile.py in _TFileConstructor(self, *args)
#      53     if len(args) >= 1:
#      54         if self.IsZombie():
# ---> 55             raise OSError('Failed to open file {}'.format(args[0]))
#      56
#      57 def _TFileOpen(klass, *args):
#
# OSError: Failed to open file /eos/user/l/llayer/cmsopen/columnar/note_v0/combine/inferno_systematic6/Fit/bce_shift_0/fit/syst/higgsCombineTest.MultiDimFit.mH120.root
# Error in <TFile::TFile>: file /eos/user/l/llayer/cmsopen/columnar/note_v0/combine/inferno_systematic6/Fit/bce_shift_0/fit/syst/higgsCombineTest.MultiDimFit.mH120.root does not exist

# %%
plt.figure(dpi=150)
shift = np.linspace(0.1,1,10)
for i in [0,2,4,6,8]:
    plt.plot(nll_bce[i][0], nll_bce[i][1] - min(nll_bce[i][1]), label="shift = " + str(round(shift[i],1)))
    plt.ylim(0,20)
plt.legend(loc="lower left")
plt.ylabel(r'$2\Delta$ NLL')
plt.xlabel(r'$\mu$')
plt.title("Binary Cross-Entropy")

# %%
plt.figure(dpi=150)
shift = np.linspace(0.1,1,10)
for i in [0,2,4,6,8]:
    plt.plot(nll_inferno_analytical[i][0], nll_inferno_analytical[i][1] - min(nll_inferno_analytical[i][1]), 
             label="shift = " + str(round(shift[i],1)))
    plt.ylim(0,20)
plt.legend(loc="lower left")
plt.ylabel(r'$2\Delta$ NLL')
plt.xlabel(r'$\mu$')
plt.title("INFERNO analytical")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-0513a0626973> in <module>
#       2 shift = np.linspace(0.1,1,10)
#       3 for i in [0,2,4,6,8]:
# ----> 4     plt.plot(nll_inferno_analytical[i][0], nll_inferno_analytical[i][1] - min(nll_inferno_analytical[i][1]),
#       5              label="shift = " + str(round(shift[i],1)))
#       6     plt.ylim(0,20)
#
# IndexError: list index out of range

# %%
plt.figure(dpi=150)
shift = np.linspace(0.1,1,10)
for i in [0,2,4,6,8]:
    plt.plot(nll_inferno_approx[i][0], nll_inferno_approx[i][1] - min(nll_inferno_approx[i][1]), 
             label="shift = " + str(round(shift[i],1)))
    plt.ylim(0,20)
plt.legend(loc="lower left")
plt.ylabel(r'$2\Delta$ NLL')
plt.xlabel(r'$\mu$')
plt.title("INFERNO approx")

# %% [markdown]
# ## Nuis

# %%
nll_bce = []
nll_inferno_analytical = []
nll_inferno_approx = []
for i in range(1,5):
    
    file_path = "/eos/user/l/llayer/cmsopen/columnar/note_v0/combine/inferno_systematic5/Fit/bce_nuis_" + str(i) + \
                 "/fit/syst/higgsCombineTest.MultiDimFit.mH120.root"
    nll_bce.append( get_graph(file_path) )
    file_path = "/eos/user/l/llayer/cmsopen/columnar/note_v0/combine/inferno_systematic5/Fit/inferno_nuis_analytical_" + str(i) + \
                 "/fit/syst/higgsCombineTest.MultiDimFit.mH120.root"
    nll_inferno_analytical.append( get_graph(file_path) )
    file_path = "/eos/user/l/llayer/cmsopen/columnar/note_v0/combine/inferno_systematic5/Fit/inferno_nuis_approx_" + str(i) + \
                 "/fit/syst/higgsCombineTest.MultiDimFit.mH120.root"
    nll_inferno_approx.append( get_graph(file_path) )

# %%
for i in range(3):
    plt.plot(nll_bce[i][0], nll_bce[i][1] - min(nll_bce[i][1]), label = "#NP = " + str(i+1))
    plt.ylim(0,20)
    plt.legend(loc="lower left")
    plt.ylabel(r'$2\Delta$ NLL')
    plt.xlabel(r'$\mu$')
    plt.title("BCE")

# %%
for i in range(3):
    plt.plot(nll_inferno_analytical[i][0], nll_inferno_analytical[i][1] - min(nll_inferno_analytical[i][1]), 
             label = "#NP = " + str(i+1))
    plt.ylim(0,20)
    plt.legend(loc="lower left")
    plt.ylabel(r'$2\Delta$ NLL')
    plt.xlabel(r'$\mu$')
    plt.title("INFERNO analytical")

# %%
for i in range(3):
    plt.plot(nll_inferno_approx[i][0], nll_inferno_approx[i][1] - min(nll_inferno_approx[i][1]), 
             label = "#NP = " + str(i+1))
    plt.ylim(0,20)
    plt.legend(loc="lower left")
    plt.ylabel(r'$2\Delta$ NLL')
    plt.xlabel(r'$\mu$')
    plt.title("INFERNO approx")

# %%
for i in range(3):
    plt.figure(dpi=150)
    plt.plot(nll_bce[i][0], nll_bce[i][1] - min(nll_bce[i][1]), label="BCE")
    plt.plot(nll_inferno_analytical[i][0], nll_inferno_analytical[i][1] - min(nll_inferno_analytical[i][1]), 
             label = "INFERNO analytical")
    plt.plot(nll_inferno_approx[i][0], nll_inferno_approx[i][1] - min(nll_inferno_approx[i][1]), 
             label = "INFERNO approx")
    plt.ylim(0,20)
    plt.legend(loc="upper left", framealpha=1.)
    plt.ylabel(r'$2\Delta$ NLL')
    plt.xlabel(r'$\mu$')
    plt.title("#NP = " + str(i+1))
    plt.show()

# %%
plt.plot(nll_inferno_approx[3][0], nll_inferno_approx[3][1] - min(nll_inferno_approx[3][1]))

# %% [markdown]
# ## Sys 6
